# %% [markdown]
# <a href="https://colab.research.google.com/github/norayehia/Machine-learning-kafka-data/blob/main/norkafka1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #*problem1*
# cicids_static_data

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv('/content/drive/MyDrive/aics/assinm2/cicids_static_data.csv')

# %%
df
# Out:
#         Destination Port   Flow Duration  ...   Idle Min   Label
# 0                     53             159  ...          0  BENIGN
# 1                     53           51673  ...          0  BENIGN
# 2                   7496              43  ...          0  ATTACK
# 3                  46564              61  ...          0  BENIGN
# 4                     80              69  ...          0  BENIGN
# ...                  ...             ...  ...        ...     ...
# 25186              50100             197  ...          0  BENIGN
# 25187               3390              48  ...          0  ATTACK
# 25188                123             117  ...          0  BENIGN
# 25189                443       116260101  ...    5201068  BENIGN
# 25190                443         1334422  ...          0  BENIGN
#
# [25191 rows x 79 columns]

# %% [markdown]
# #preproceeesing
#
# REPLACE INFINTE VALUES FROM COLUMN  WITH NAN THEN REPLACE ALL NAN WITH ZERO

# %%
df.shape
# Out:
# (25191, 79)

# %%
#df = df.reset_index()

# %% [markdown]
# REPLACE INFINTE VALUES FROM COLUMN  WITH NAN

# %%
df.replace([np.inf, -np.inf], np.nan, inplace=True)

# %%
df.isnull().sum().max()
# Out:
# 12

# %%
df = df.fillna(0)

# %%
df.isnull().sum().max()
# Out:
# 0

# %%
df.shape
# Out:
# (25191, 79)

# %% [markdown]
# Remove any white spaces at the end of the string  to make the feature names like kafka

# %%
df = df.rename(columns={c:c.strip() for c in df.columns})

# %%
pip install category_encoders
# Out:
# Collecting category_encoders
#   Downloading category_encoders-2.3.0-py2.py3-none-any.whl (82 kB)
#      |████████████████████████████████| 82 kB 300 kB/s
# Requirement already satisfied: pandas>=0.21.1 in /usr/local/lib/python3.7/dist-packages (from category_encoders) (1.1.5)
# Requirement already satisfied: patsy>=0.5.1 in /usr/local/lib/python3.7/dist-packages (from category_encoders) (0.5.2)
# Requirement already satisfied: scipy>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from category_encoders) (1.4.1)
# Requirement already satisfied: statsmodels>=0.9.0 in /usr/local/lib/python3.7/dist-packages (from category_encoders) (0.10.2)
# Requirement already satisfied: numpy>=1.14.0 in /usr/local/lib/python3.7/dist-packages (from category_encoders) (1.19.5)
# Requirement already satisfied: scikit-learn>=0.20.0 in /usr/local/lib/python3.7/dist-packages (from category_encoders) (1.0.1)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.21.1->category_encoders) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.21.1->category_encoders) (2.8.2)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from patsy>=0.5.1->category_encoders) (1.15.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.20.0->category_encoders) (3.0.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.20.0->category_encoders) (1.1.0)
# Installing collected packages: category-encoders
# Successfully installed category-encoders-2.3.0

# %% [markdown]
# A set of scikit-learn-style transformers for encoding categorical variables into numeric with different techniques.
# ce.OrdinalEncoder
#
# The input to this transformer should be an array-like of integers or strings, denoting the values taken on by categorical (discrete) features. The features are converted to ordinal integers. This results in a single column of integers (0 to n_categories - 1) per feature

# %%
import category_encoders as ce


# encode categorical variables with ordinal encoding

encoder = ce.OrdinalEncoder(cols=['Label'])


df = encoder.fit_transform(df)

# %%
#df.info()

# %%
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split


#X = df.drop(['Fwd PSH Flags','Bwd PSH Flags','Fwd URG Flags','Bwd URG Flags','Label'],axis=1)
X = df.drop(['Label'],axis=1)
y =df['Label']

# %%
df.shape
# Out:
# (25191, 79)

# %%
X_train,X_test,Y_train,Y_test = train_test_split(X,y,test_size=.20,random_state=42)
print("shape of X Train :"+str(X_train.shape))
print("shape of X Test :"+str(X_test.shape))
print("shape of Y Train :"+str(Y_train.shape))
print("shape of Y Test :"+str(Y_test.shape))
# Out:
# shape of X Train :(20152, 78)
# shape of X Test :(5039, 78)
# shape of Y Train :(20152,)
# shape of Y Test :(5039,)

# %% [markdown]
# #fit rondom forest on the static data
# #first algorithm is random forest
# Random forests or random decision forests are an ensemble learning method for classification, regression and other tasks that operates by constructing a multitude of decision trees at training time. For classification tasks, the output of the random forest is the class selected by most trees,in tunning
# when using randomstate with zero THE FP WITH SECOND CLASS INCREASE randomstate with 12 give me better accuracy .99 AND 100  AND FP OF SEND CLASS IS LESS ACORDING TO CONFUSION MATRIX
# F1SCORE IS 1

# %%
# import Random Forest classifier

from sklearn.ensemble import RandomForestClassifier



# instantiate the classifier 

rfc = RandomForestClassifier(random_state=12,n_estimators=100,)



# fit the model

rfc.fit(X_train, Y_train)
# Out:
# RandomForestClassifier(random_state=12)

# %%
y_pred = rfc.predict(X_test)

from sklearn.metrics import accuracy_score

# Check accuracy score 

print('Model accuracy score with doors variable removed : {0:0.4f}'. format(accuracy_score(Y_test, y_pred)))
# Out:
# Model accuracy score with doors variable removed : 0.9960

# %%
# Print the Confusion Matrix and slice it into four pieces

from sklearn.metrics import confusion_matrix

cm = confusion_matrix(Y_test, y_pred)

print('Confusion matrix\n\n', cm)
# Out:
# Confusion matrix
#
#  [[4522    1]
#  [  19  497]]

# %%
from sklearn.metrics import plot_confusion_matrix
plot_confusion_matrix(rfc, X_test, Y_test)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)

# %% [markdown]
# the model predict well class 1 fp is 2 only

# %%
from sklearn.metrics import classification_report

print(classification_report(Y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00      4523
#            2       1.00      0.96      0.98       516
#
#     accuracy                           1.00      5039
#    macro avg       1.00      0.98      0.99      5039
# weighted avg       1.00      1.00      1.00      5039

# %%
y_pred
# Out:
# array([1, 1, 1, ..., 2, 1, 1])

# %% [markdown]
# #second classfier
#  MLPClassifier trains iteratively since at each time step the partial derivatives of the loss function with respect to the model parameters are computed to update the parameters. when tunning mlp with randomstate 5,max iteraton 300  give me .94 accracy  and fp is 96 // it give me .90 accuracy when tunng with random state 7 and max iteration 300 so its better with 300 and fp is 118 higher

# %%
from sklearn.neural_network import MLPClassifier
clf = MLPClassifier(random_state=5, max_iter=300).fit(X_train, Y_train)

# %%
y_predm = clf.predict(X_test)

from sklearn.metrics import accuracy_score

# Check accuracy score 

print('Model accuracy score with doors variable removed : {0:0.4f}'. format(accuracy_score(Y_test, y_predm)))
# Out:
# Model accuracy score with doors variable removed : 0.9480

# %%
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(Y_test, y_predm)

print('Confusion matrix\n\n', cm)
# Out:
# Confusion matrix
#
#  [[4427   96]
#  [ 166  350]]

# %%
from sklearn.metrics import plot_confusion_matrix
plot_confusion_matrix(clf, X_test, Y_test)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)

# %%
from sklearn.metrics import classification_report

print(classification_report(Y_test, y_predm))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.96      0.98      0.97      4523
#            2       0.78      0.68      0.73       516
#
#     accuracy                           0.95      5039
#    macro avg       0.87      0.83      0.85      5039
# weighted avg       0.95      0.95      0.95      5039

# %% [markdown]
# #kAFkA

# %% [markdown]
# on static data show that rondomforest is better on this problem
# acording to f1score and acuracy and confusion matrix the fp for the classes increases

# %%
# Make sure that you have the dependency installed on your system
# If not installed, install by running the following
# !pip install kafka-python
# Out:
# Collecting kafka-python
#   Downloading kafka_python-2.0.2-py2.py3-none-any.whl (246 kB)
#      |████████████████████████████████| 246 kB 5.1 MB/s
# Installing collected packages: kafka-python
# Successfully installed kafka-python-2.0.2

# %%
import time
import ast
from numpy import nan
from math import *
#inf=math.inf

# Import the python Consumer Client for Kafka
from kafka import KafkaConsumer

# instantiate the KafkaConsumer Class using the arguments mentioned.
# do not change any arguments other than the first positional argument.
consumer = KafkaConsumer(
    'task1',   # change this to "task2" for the IOT Botnet Detection  ---- important ----
    bootstrap_servers="34.130.121.39:9092",
    sasl_plain_username="student",
    sasl_plain_password="uottawa",
    security_protocol="SASL_PLAINTEXT",
    sasl_mechanism="PLAIN",
    auto_offset_reset='earliest',
    enable_auto_commit=False
)

i =1 
dat=[]
for message in consumer:
    print(f"Consuming the {i+1}th data packet!")
    
    data_packet = message.value
    try:
      data_packet=ast.literal_eval(data_packet.decode("utf-8"))
    except ValueError:
      continue
    dat.append(data_packet)  
#     print(data_packet)
    
 ##############################################
    
    if i == 100000:
        break
        
    i += 1
# Out:
# Streaming output truncated to the last 5000 lines.
# Consuming the 95010th data packet!
# Consuming the 95011th data packet!
# Consuming the 95012th data packet!
# Consuming the 95013th data packet!
# Consuming the 95014th data packet!
# Consuming the 95015th data packet!
# Consuming the 95016th data packet!
# Consuming the 95017th data packet!
# Consuming the 95018th data packet!
# Consuming the 95019th data packet!
# Consuming the 95020th data packet!
# Consuming the 95021th data packet!
# Consuming the 95022th data packet!
# Consuming the 95023th data packet!
# Consuming the 95024th data packet!
# Consuming the 95025th data packet!
# Consuming the 95026th data packet!
# Consuming the 95027th data packet!
# Consuming the 95028th data packet!
# Consuming the 95029th data packet!
# Consuming the 95030th data packet!
# Consuming the 95031th data packet!
# Consuming the 95032th data packet!
# Consuming the 95033th data packet!
# Consuming the 95034th data packet!
# Consuming the 95035th data packet!
# Consuming the 95036th data packet!
# Consuming the 95037th data packet!
# Consuming the 95038th data packet!
# Consuming the 95039th data packet!
# Consuming the 95040th data packet!
# Consuming the 95041th data packet!
# Consuming the 95042th data packet!
# Consuming the 95043th data packet!
# Consuming the 95044th data packet!
# Consuming the 95045th data packet!
# Consuming the 95046th data packet!
# Consuming the 95047th data packet!
# Consuming the 95048th data packet!
# Consuming the 95049th data packet!
# Consuming the 95050th data packet!
# Consuming the 95051th data packet!
# Consuming the 95052th data packet!
# Consuming the 95053th data packet!
# Consuming the 95054th data packet!
# Consuming the 95055th data packet!
# Consuming the 95056th data packet!
# Consuming the 95057th data packet!
# Consuming the 95058th data packet!
# Consuming the 95059th data packet!
# Consuming the 95060th data packet!
# Consuming the 95061th data packet!
# Consuming the 95062th data packet!
# Consuming the 95063th data packet!
# Consuming the 95064th data packet!
# Consuming the 95065th data packet!
# Consuming the 95066th data packet!
# Consuming the 95067th data packet!
# Consuming the 95068th data packet!
# Consuming the 95069th data packet!
# Consuming the 95070th data packet!
# Consuming the 95071th data packet!
# Consuming the 95072th data packet!
# Consuming the 95073th data packet!
# Consuming the 95074th data packet!
# Consuming the 95075th data packet!
# Consuming the 95076th data packet!
# Consuming the 95077th data packet!
# Consuming the 95078th data packet!
# Consuming the 95079th data packet!
# Consuming the 95080th data packet!
# Consuming the 95081th data packet!
# Consuming the 95082th data packet!
# Consuming the 95083th data packet!
# Consuming the 95084th data packet!
# Consuming the 95085th data packet!
# Consuming the 95086th data packet!
# Consuming the 95087th data packet!
# Consuming the 95088th data packet!
# Consuming the 95089th data packet!
# Consuming the 95090th data packet!
# Consuming the 95091th data packet!
# Consuming the 95092th data packet!
# Consuming the 95093th data packet!
# Consuming the 95094th data packet!
# Consuming the 95095th data packet!
# Consuming the 95096th data packet!
# Consuming the 95097th data packet!
# Consuming the 95098th data packet!
# Consuming the 95099th data packet!
# Consuming the 95100th data packet!
# Consuming the 95101th data packet!
# Consuming the 95102th data packet!
# Consuming the 95103th data packet!
# Consuming the 95104th data packet!
# Consuming the 95105th data packet!
# Consuming the 95106th data packet!
# Consuming the 95107th data packet!
# Consuming the 95108th data packet!
# Consuming the 95109th data packet!
# Consuming the 95110th data packet!
# Consuming the 95111th data packet!
# Consuming the 95112th data packet!
# Consuming the 95113th data packet!
# Consuming the 95114th data packet!
# Consuming the 95115th data packet!
# Consuming the 95116th data packet!
# Consuming the 95117th data packet!
# Consuming the 95118th data packet!
# Consuming the 95119th data packet!
# Consuming the 95120th data packet!
# Consuming the 95121th data packet!
# Consuming the 95122th data packet!
# Consuming the 95123th data packet!
# Consuming the 95124th data packet!
# Consuming the 95125th data packet!
# Consuming the 95126th data packet!
# Consuming the 95127th data packet!
# Consuming the 95128th data packet!
# Consuming the 95129th data packet!
# Consuming the 95130th data packet!
# Consuming the 95131th data packet!
# Consuming the 95132th data packet!
# Consuming the 95133th data packet!
# Consuming the 95134th data packet!
# Consuming the 95135th data packet!
# Consuming the 95136th data packet!
# Consuming the 95137th data packet!
# Consuming the 95138th data packet!
# Consuming the 95139th data packet!
# Consuming the 95140th data packet!
# Consuming the 95141th data packet!
# Consuming the 95142th data packet!
# Consuming the 95143th data packet!
# Consuming the 95144th data packet!
# Consuming the 95145th data packet!
# Consuming the 95146th data packet!
# Consuming the 95147th data packet!
# Consuming the 95148th data packet!
# Consuming the 95149th data packet!
# Consuming the 95150th data packet!
# Consuming the 95151th data packet!
# Consuming the 95152th data packet!
# Consuming the 95153th data packet!
# Consuming the 95154th data packet!
# Consuming the 95155th data packet!
# Consuming the 95156th data packet!
# Consuming the 95157th data packet!
# Consuming the 95158th data packet!
# Consuming the 95159th data packet!
# Consuming the 95160th data packet!
# Consuming the 95161th data packet!
# Consuming the 95162th data packet!
# Consuming the 95163th data packet!
# Consuming the 95164th data packet!
# Consuming the 95165th data packet!
# Consuming the 95166th data packet!
# Consuming the 95167th data packet!
# Consuming the 95168th data packet!
# Consuming the 95169th data packet!
# Consuming the 95170th data packet!
# Consuming the 95171th data packet!
# Consuming the 95172th data packet!
# Consuming the 95173th data packet!
# Consuming the 95174th data packet!
# Consuming the 95175th data packet!
# Consuming the 95176th data packet!
# Consuming the 95177th data packet!
# Consuming the 95178th data packet!
# Consuming the 95179th data packet!
# Consuming the 95180th data packet!
# Consuming the 95181th data packet!
# Consuming the 95182th data packet!
# Consuming the 95183th data packet!
# Consuming the 95184th data packet!
# Consuming the 95185th data packet!
# Consuming the 95186th data packet!
# Consuming the 95187th data packet!
# Consuming the 95188th data packet!
# Consuming the 95189th data packet!
# Consuming the 95190th data packet!
# Consuming the 95191th data packet!
# Consuming the 95192th data packet!
# Consuming the 95193th data packet!
# Consuming the 95194th data packet!
# Consuming the 95195th data packet!
# Consuming the 95196th data packet!
# Consuming the 95197th data packet!
# Consuming the 95198th data packet!
# Consuming the 95199th data packet!
# Consuming the 95200th data packet!
# Consuming the 95201th data packet!
# Consuming the 95202th data packet!
# Consuming the 95203th data packet!
# Consuming the 95204th data packet!
# Consuming the 95205th data packet!
# Consuming the 95206th data packet!
# Consuming the 95207th data packet!
# Consuming the 95208th data packet!
# Consuming the 95209th data packet!
# Consuming the 95210th data packet!
# Consuming the 95211th data packet!
# Consuming the 95212th data packet!
# Consuming the 95213th data packet!
# Consuming the 95214th data packet!
# Consuming the 95215th data packet!
# Consuming the 95216th data packet!
# Consuming the 95217th data packet!
# Consuming the 95218th data packet!
# Consuming the 95219th data packet!
# Consuming the 95220th data packet!
# Consuming the 95221th data packet!
# Consuming the 95222th data packet!
# Consuming the 95223th data packet!
# Consuming the 95224th data packet!
# Consuming the 95225th data packet!
# Consuming the 95226th data packet!
# Consuming the 95227th data packet!
# Consuming the 95228th data packet!
# Consuming the 95229th data packet!
# Consuming the 95230th data packet!
# Consuming the 95231th data packet!
# Consuming the 95232th data packet!
# Consuming the 95233th data packet!
# Consuming the 95234th data packet!
# Consuming the 95235th data packet!
# Consuming the 95236th data packet!
# Consuming the 95237th data packet!
# Consuming the 95238th data packet!
# Consuming the 95239th data packet!
# Consuming the 95240th data packet!
# Consuming the 95241th data packet!
# Consuming the 95242th data packet!
# Consuming the 95243th data packet!
# Consuming the 95244th data packet!
# Consuming the 95245th data packet!
# Consuming the 95246th data packet!
# Consuming the 95247th data packet!
# Consuming the 95248th data packet!
# Consuming the 95249th data packet!
# Consuming the 95250th data packet!
# Consuming the 95251th data packet!
# Consuming the 95252th data packet!
# Consuming the 95253th data packet!
# Consuming the 95254th data packet!
# Consuming the 95255th data packet!
# Consuming the 95256th data packet!
# Consuming the 95257th data packet!
# Consuming the 95258th data packet!
# Consuming the 95259th data packet!
# Consuming the 95260th data packet!
# Consuming the 95261th data packet!
# Consuming the 95262th data packet!
# Consuming the 95263th data packet!
# Consuming the 95264th data packet!
# Consuming the 95265th data packet!
# Consuming the 95266th data packet!
# Consuming the 95267th data packet!
# Consuming the 95268th data packet!
# Consuming the 95269th data packet!
# Consuming the 95270th data packet!
# Consuming the 95271th data packet!
# Consuming the 95272th data packet!
# Consuming the 95273th data packet!
# Consuming the 95274th data packet!
# Consuming the 95275th data packet!
# Consuming the 95276th data packet!
# Consuming the 95277th data packet!
# Consuming the 95278th data packet!
# Consuming the 95279th data packet!
# Consuming the 95280th data packet!
# Consuming the 95281th data packet!
# Consuming the 95282th data packet!
# Consuming the 95283th data packet!
# Consuming the 95284th data packet!
# Consuming the 95285th data packet!
# Consuming the 95286th data packet!
# Consuming the 95287th data packet!
# Consuming the 95288th data packet!
# Consuming the 95289th data packet!
# Consuming the 95290th data packet!
# Consuming the 95291th data packet!
# Consuming the 95292th data packet!
# Consuming the 95293th data packet!
# Consuming the 95294th data packet!
# Consuming the 95295th data packet!
# Consuming the 95296th data packet!
# Consuming the 95297th data packet!
# Consuming the 95298th data packet!
# Consuming the 95299th data packet!
# Consuming the 95300th data packet!
# Consuming the 95301th data packet!
# Consuming the 95302th data packet!
# Consuming the 95303th data packet!
# Consuming the 95304th data packet!
# Consuming the 95305th data packet!
# Consuming the 95306th data packet!
# Consuming the 95307th data packet!
# Consuming the 95308th data packet!
# Consuming the 95309th data packet!
# Consuming the 95310th data packet!
# Consuming the 95311th data packet!
# Consuming the 95312th data packet!
# Consuming the 95313th data packet!
# Consuming the 95314th data packet!
# Consuming the 95315th data packet!
# Consuming the 95316th data packet!
# Consuming the 95317th data packet!
# Consuming the 95318th data packet!
# Consuming the 95319th data packet!
# Consuming the 95320th data packet!
# Consuming the 95321th data packet!
# Consuming the 95322th data packet!
# Consuming the 95323th data packet!
# Consuming the 95324th data packet!
# Consuming the 95325th data packet!
# Consuming the 95326th data packet!
# Consuming the 95327th data packet!
# Consuming the 95328th data packet!
# Consuming the 95329th data packet!
# Consuming the 95330th data packet!
# Consuming the 95331th data packet!
# Consuming the 95332th data packet!
# Consuming the 95333th data packet!
# Consuming the 95334th data packet!
# Consuming the 95335th data packet!
# Consuming the 95336th data packet!
# Consuming the 95337th data packet!
# Consuming the 95338th data packet!
# Consuming the 95339th data packet!
# Consuming the 95340th data packet!
# Consuming the 95341th data packet!
# Consuming the 95342th data packet!
# Consuming the 95343th data packet!
# Consuming the 95344th data packet!
# Consuming the 95345th data packet!
# Consuming the 95346th data packet!
# Consuming the 95347th data packet!
# Consuming the 95348th data packet!
# Consuming the 95349th data packet!
# Consuming the 95350th data packet!
# Consuming the 95351th data packet!
# Consuming the 95352th data packet!
# Consuming the 95353th data packet!
# Consuming the 95354th data packet!
# Consuming the 95355th data packet!
# Consuming the 95356th data packet!
# Consuming the 95357th data packet!
# Consuming the 95358th data packet!
# Consuming the 95359th data packet!
# Consuming the 95360th data packet!
# Consuming the 95361th data packet!
# Consuming the 95362th data packet!
# Consuming the 95363th data packet!
# Consuming the 95364th data packet!
# Consuming the 95365th data packet!
# Consuming the 95366th data packet!
# Consuming the 95367th data packet!
# Consuming the 95368th data packet!
# Consuming the 95369th data packet!
# Consuming the 95370th data packet!
# Consuming the 95371th data packet!
# Consuming the 95372th data packet!
# Consuming the 95373th data packet!
# Consuming the 95374th data packet!
# Consuming the 95375th data packet!
# Consuming the 95376th data packet!
# Consuming the 95377th data packet!
# Consuming the 95378th data packet!
# Consuming the 95379th data packet!
# Consuming the 95380th data packet!
# Consuming the 95381th data packet!
# Consuming the 95382th data packet!
# Consuming the 95383th data packet!
# Consuming the 95384th data packet!
# Consuming the 95385th data packet!
# Consuming the 95386th data packet!
# Consuming the 95387th data packet!
# Consuming the 95388th data packet!
# Consuming the 95389th data packet!
# Consuming the 95390th data packet!
# Consuming the 95391th data packet!
# Consuming the 95392th data packet!
# Consuming the 95393th data packet!
# Consuming the 95394th data packet!
# Consuming the 95395th data packet!
# Consuming the 95396th data packet!
# Consuming the 95397th data packet!
# Consuming the 95398th data packet!
# Consuming the 95399th data packet!
# Consuming the 95400th data packet!
# Consuming the 95401th data packet!
# Consuming the 95402th data packet!
# Consuming the 95403th data packet!
# Consuming the 95404th data packet!
# Consuming the 95405th data packet!
# Consuming the 95406th data packet!
# Consuming the 95407th data packet!
# Consuming the 95408th data packet!
# Consuming the 95409th data packet!
# Consuming the 95410th data packet!
# Consuming the 95411th data packet!
# Consuming the 95412th data packet!
# Consuming the 95413th data packet!
# Consuming the 95414th data packet!
# Consuming the 95415th data packet!
# Consuming the 95416th data packet!
# Consuming the 95417th data packet!
# Consuming the 95418th data packet!
# Consuming the 95419th data packet!
# Consuming the 95420th data packet!
# Consuming the 95421th data packet!
# Consuming the 95422th data packet!
# Consuming the 95423th data packet!
# Consuming the 95424th data packet!
# Consuming the 95425th data packet!
# Consuming the 95426th data packet!
# Consuming the 95427th data packet!
# Consuming the 95428th data packet!
# Consuming the 95429th data packet!
# Consuming the 95430th data packet!
# Consuming the 95431th data packet!
# Consuming the 95432th data packet!
# Consuming the 95433th data packet!
# Consuming the 95434th data packet!
# Consuming the 95435th data packet!
# Consuming the 95436th data packet!
# Consuming the 95437th data packet!
# Consuming the 95438th data packet!
# Consuming the 95439th data packet!
# Consuming the 95440th data packet!
# Consuming the 95441th data packet!
# Consuming the 95442th data packet!
# Consuming the 95443th data packet!
# Consuming the 95444th data packet!
# Consuming the 95445th data packet!
# Consuming the 95446th data packet!
# Consuming the 95447th data packet!
# Consuming the 95448th data packet!
# Consuming the 95449th data packet!
# Consuming the 95450th data packet!
# Consuming the 95451th data packet!
# Consuming the 95452th data packet!
# Consuming the 95453th data packet!
# Consuming the 95454th data packet!
# Consuming the 95455th data packet!
# Consuming the 95456th data packet!
# Consuming the 95457th data packet!
# Consuming the 95458th data packet!
# Consuming the 95459th data packet!
# Consuming the 95460th data packet!
# Consuming the 95461th data packet!
# Consuming the 95462th data packet!
# Consuming the 95463th data packet!
# Consuming the 95464th data packet!
# Consuming the 95465th data packet!
# Consuming the 95466th data packet!
# Consuming the 95467th data packet!
# Consuming the 95468th data packet!
# Consuming the 95469th data packet!
# Consuming the 95470th data packet!
# Consuming the 95471th data packet!
# Consuming the 95472th data packet!
# Consuming the 95473th data packet!
# Consuming the 95474th data packet!
# Consuming the 95475th data packet!
# Consuming the 95476th data packet!
# Consuming the 95477th data packet!
# Consuming the 95478th data packet!
# Consuming the 95479th data packet!
# Consuming the 95480th data packet!
# Consuming the 95481th data packet!
# Consuming the 95482th data packet!
# Consuming the 95483th data packet!
# Consuming the 95484th data packet!
# Consuming the 95485th data packet!
# Consuming the 95486th data packet!
# Consuming the 95487th data packet!
# Consuming the 95488th data packet!
# Consuming the 95489th data packet!
# Consuming the 95490th data packet!
# Consuming the 95491th data packet!
# Consuming the 95492th data packet!
# Consuming the 95493th data packet!
# Consuming the 95494th data packet!
# Consuming the 95495th data packet!
# Consuming the 95496th data packet!
# Consuming the 95497th data packet!
# Consuming the 95498th data packet!
# Consuming the 95499th data packet!
# Consuming the 95500th data packet!
# Consuming the 95501th data packet!
# Consuming the 95502th data packet!
# Consuming the 95503th data packet!
# Consuming the 95504th data packet!
# Consuming the 95505th data packet!
# Consuming the 95506th data packet!
# Consuming the 95507th data packet!
# Consuming the 95508th data packet!
# Consuming the 95509th data packet!
# Consuming the 95510th data packet!
# Consuming the 95510th data packet!
# Consuming the 95511th data packet!
# Consuming the 95512th data packet!
# Consuming the 95513th data packet!
# Consuming the 95514th data packet!
# Consuming the 95515th data packet!
# Consuming the 95516th data packet!
# Consuming the 95517th data packet!
# Consuming the 95518th data packet!
# Consuming the 95519th data packet!
# Consuming the 95520th data packet!
# Consuming the 95521th data packet!
# Consuming the 95522th data packet!
# Consuming the 95523th data packet!
# Consuming the 95524th data packet!
# Consuming the 95525th data packet!
# Consuming the 95526th data packet!
# Consuming the 95527th data packet!
# Consuming the 95528th data packet!
# Consuming the 95529th data packet!
# Consuming the 95530th data packet!
# Consuming the 95531th data packet!
# Consuming the 95532th data packet!
# Consuming the 95533th data packet!
# Consuming the 95534th data packet!
# Consuming the 95535th data packet!
# Consuming the 95536th data packet!
# Consuming the 95537th data packet!
# Consuming the 95538th data packet!
# Consuming the 95539th data packet!
# Consuming the 95540th data packet!
# Consuming the 95541th data packet!
# Consuming the 95542th data packet!
# Consuming the 95543th data packet!
# Consuming the 95544th data packet!
# Consuming the 95545th data packet!
# Consuming the 95546th data packet!
# Consuming the 95547th data packet!
# Consuming the 95548th data packet!
# Consuming the 95549th data packet!
# Consuming the 95550th data packet!
# Consuming the 95551th data packet!
# Consuming the 95552th data packet!
# Consuming the 95553th data packet!
# Consuming the 95554th data packet!
# Consuming the 95555th data packet!
# Consuming the 95556th data packet!
# Consuming the 95557th data packet!
# Consuming the 95558th data packet!
# Consuming the 95559th data packet!
# Consuming the 95560th data packet!
# Consuming the 95561th data packet!
# Consuming the 95562th data packet!
# Consuming the 95563th data packet!
# Consuming the 95564th data packet!
# Consuming the 95565th data packet!
# Consuming the 95566th data packet!
# Consuming the 95567th data packet!
# Consuming the 95568th data packet!
# Consuming the 95569th data packet!
# Consuming the 95570th data packet!
# Consuming the 95571th data packet!
# Consuming the 95572th data packet!
# Consuming the 95573th data packet!
# Consuming the 95574th data packet!
# Consuming the 95575th data packet!
# Consuming the 95576th data packet!
# Consuming the 95577th data packet!
# Consuming the 95578th data packet!
# Consuming the 95579th data packet!
# Consuming the 95580th data packet!
# Consuming the 95581th data packet!
# Consuming the 95582th data packet!
# Consuming the 95583th data packet!
# Consuming the 95584th data packet!
# Consuming the 95585th data packet!
# Consuming the 95586th data packet!
# Consuming the 95587th data packet!
# Consuming the 95588th data packet!
# Consuming the 95589th data packet!
# Consuming the 95590th data packet!
# Consuming the 95591th data packet!
# Consuming the 95592th data packet!
# Consuming the 95593th data packet!
# Consuming the 95594th data packet!
# Consuming the 95595th data packet!
# Consuming the 95596th data packet!
# Consuming the 95597th data packet!
# Consuming the 95598th data packet!
# Consuming the 95599th data packet!
# Consuming the 95600th data packet!
# Consuming the 95601th data packet!
# Consuming the 95602th data packet!
# Consuming the 95603th data packet!
# Consuming the 95604th data packet!
# Consuming the 95605th data packet!
# Consuming the 95606th data packet!
# Consuming the 95607th data packet!
# Consuming the 95608th data packet!
# Consuming the 95609th data packet!
# Consuming the 95610th data packet!
# Consuming the 95611th data packet!
# Consuming the 95612th data packet!
# Consuming the 95613th data packet!
# Consuming the 95614th data packet!
# Consuming the 95615th data packet!
# Consuming the 95616th data packet!
# Consuming the 95617th data packet!
# Consuming the 95618th data packet!
# Consuming the 95619th data packet!
# Consuming the 95620th data packet!
# Consuming the 95621th data packet!
# Consuming the 95622th data packet!
# Consuming the 95623th data packet!
# Consuming the 95624th data packet!
# Consuming the 95625th data packet!
# Consuming the 95626th data packet!
# Consuming the 95627th data packet!
# Consuming the 95628th data packet!
# Consuming the 95629th data packet!
# Consuming the 95630th data packet!
# Consuming the 95631th data packet!
# Consuming the 95632th data packet!
# Consuming the 95633th data packet!
# Consuming the 95634th data packet!
# Consuming the 95635th data packet!
# Consuming the 95636th data packet!
# Consuming the 95637th data packet!
# Consuming the 95638th data packet!
# Consuming the 95639th data packet!
# Consuming the 95640th data packet!
# Consuming the 95641th data packet!
# Consuming the 95642th data packet!
# Consuming the 95643th data packet!
# Consuming the 95644th data packet!
# Consuming the 95645th data packet!
# Consuming the 95646th data packet!
# Consuming the 95647th data packet!
# Consuming the 95648th data packet!
# Consuming the 95649th data packet!
# Consuming the 95650th data packet!
# Consuming the 95651th data packet!
# Consuming the 95652th data packet!
# Consuming the 95653th data packet!
# Consuming the 95654th data packet!
# Consuming the 95655th data packet!
# Consuming the 95656th data packet!
# Consuming the 95657th data packet!
# Consuming the 95658th data packet!
# Consuming the 95659th data packet!
# Consuming the 95660th data packet!
# Consuming the 95661th data packet!
# Consuming the 95662th data packet!
# Consuming the 95663th data packet!
# Consuming the 95664th data packet!
# Consuming the 95665th data packet!
# Consuming the 95666th data packet!
# Consuming the 95667th data packet!
# Consuming the 95668th data packet!
# Consuming the 95669th data packet!
# Consuming the 95670th data packet!
# Consuming the 95671th data packet!
# Consuming the 95672th data packet!
# Consuming the 95673th data packet!
# Consuming the 95674th data packet!
# Consuming the 95675th data packet!
# Consuming the 95676th data packet!
# Consuming the 95677th data packet!
# Consuming the 95678th data packet!
# Consuming the 95679th data packet!
# Consuming the 95680th data packet!
# Consuming the 95681th data packet!
# Consuming the 95682th data packet!
# Consuming the 95683th data packet!
# Consuming the 95684th data packet!
# Consuming the 95685th data packet!
# Consuming the 95686th data packet!
# Consuming the 95687th data packet!
# Consuming the 95688th data packet!
# Consuming the 95689th data packet!
# Consuming the 95690th data packet!
# Consuming the 95691th data packet!
# Consuming the 95692th data packet!
# Consuming the 95693th data packet!
# Consuming the 95694th data packet!
# Consuming the 95695th data packet!
# Consuming the 95696th data packet!
# Consuming the 95697th data packet!
# Consuming the 95698th data packet!
# Consuming the 95699th data packet!
# Consuming the 95700th data packet!
# Consuming the 95701th data packet!
# Consuming the 95702th data packet!
# Consuming the 95703th data packet!
# Consuming the 95704th data packet!
# Consuming the 95705th data packet!
# Consuming the 95706th data packet!
# Consuming the 95707th data packet!
# Consuming the 95708th data packet!
# Consuming the 95709th data packet!
# Consuming the 95710th data packet!
# Consuming the 95711th data packet!
# Consuming the 95712th data packet!
# Consuming the 95713th data packet!
# Consuming the 95714th data packet!
# Consuming the 95715th data packet!
# Consuming the 95716th data packet!
# Consuming the 95717th data packet!
# Consuming the 95718th data packet!
# Consuming the 95719th data packet!
# Consuming the 95720th data packet!
# Consuming the 95721th data packet!
# Consuming the 95722th data packet!
# Consuming the 95723th data packet!
# Consuming the 95724th data packet!
# Consuming the 95725th data packet!
# Consuming the 95726th data packet!
# Consuming the 95727th data packet!
# Consuming the 95728th data packet!
# Consuming the 95729th data packet!
# Consuming the 95730th data packet!
# Consuming the 95731th data packet!
# Consuming the 95732th data packet!
# Consuming the 95733th data packet!
# Consuming the 95734th data packet!
# Consuming the 95735th data packet!
# Consuming the 95736th data packet!
# Consuming the 95737th data packet!
# Consuming the 95738th data packet!
# Consuming the 95739th data packet!
# Consuming the 95740th data packet!
# Consuming the 95741th data packet!
# Consuming the 95742th data packet!
# Consuming the 95743th data packet!
# Consuming the 95744th data packet!
# Consuming the 95745th data packet!
# Consuming the 95746th data packet!
# Consuming the 95747th data packet!
# Consuming the 95748th data packet!
# Consuming the 95749th data packet!
# Consuming the 95750th data packet!
# Consuming the 95751th data packet!
# Consuming the 95752th data packet!
# Consuming the 95753th data packet!
# Consuming the 95754th data packet!
# Consuming the 95755th data packet!
# Consuming the 95756th data packet!
# Consuming the 95757th data packet!
# Consuming the 95758th data packet!
# Consuming the 95759th data packet!
# Consuming the 95760th data packet!
# Consuming the 95761th data packet!
# Consuming the 95762th data packet!
# Consuming the 95763th data packet!
# Consuming the 95764th data packet!
# Consuming the 95765th data packet!
# Consuming the 95766th data packet!
# Consuming the 95767th data packet!
# Consuming the 95768th data packet!
# Consuming the 95769th data packet!
# Consuming the 95770th data packet!
# Consuming the 95771th data packet!
# Consuming the 95772th data packet!
# Consuming the 95773th data packet!
# Consuming the 95774th data packet!
# Consuming the 95775th data packet!
# Consuming the 95776th data packet!
# Consuming the 95777th data packet!
# Consuming the 95778th data packet!
# Consuming the 95779th data packet!
# Consuming the 95780th data packet!
# Consuming the 95781th data packet!
# Consuming the 95782th data packet!
# Consuming the 95783th data packet!
# Consuming the 95784th data packet!
# Consuming the 95785th data packet!
# Consuming the 95786th data packet!
# Consuming the 95787th data packet!
# Consuming the 95788th data packet!
# Consuming the 95789th data packet!
# Consuming the 95790th data packet!
# Consuming the 95791th data packet!
# Consuming the 95792th data packet!
# Consuming the 95793th data packet!
# Consuming the 95794th data packet!
# Consuming the 95795th data packet!
# Consuming the 95796th data packet!
# Consuming the 95797th data packet!
# Consuming the 95798th data packet!
# Consuming the 95799th data packet!
# Consuming the 95800th data packet!
# Consuming the 95801th data packet!
# Consuming the 95802th data packet!
# Consuming the 95803th data packet!
# Consuming the 95804th data packet!
# Consuming the 95805th data packet!
# Consuming the 95806th data packet!
# Consuming the 95807th data packet!
# Consuming the 95808th data packet!
# Consuming the 95809th data packet!
# Consuming the 95810th data packet!
# Consuming the 95811th data packet!
# Consuming the 95812th data packet!
# Consuming the 95813th data packet!
# Consuming the 95814th data packet!
# Consuming the 95815th data packet!
# Consuming the 95816th data packet!
# Consuming the 95817th data packet!
# Consuming the 95818th data packet!
# Consuming the 95819th data packet!
# Consuming the 95820th data packet!
# Consuming the 95821th data packet!
# Consuming the 95822th data packet!
# Consuming the 95823th data packet!
# Consuming the 95824th data packet!
# Consuming the 95825th data packet!
# Consuming the 95826th data packet!
# Consuming the 95827th data packet!
# Consuming the 95828th data packet!
# Consuming the 95829th data packet!
# Consuming the 95830th data packet!
# Consuming the 95831th data packet!
# Consuming the 95832th data packet!
# Consuming the 95833th data packet!
# Consuming the 95834th data packet!
# Consuming the 95835th data packet!
# Consuming the 95836th data packet!
# Consuming the 95837th data packet!
# Consuming the 95838th data packet!
# Consuming the 95839th data packet!
# Consuming the 95840th data packet!
# Consuming the 95841th data packet!
# Consuming the 95842th data packet!
# Consuming the 95843th data packet!
# Consuming the 95844th data packet!
# Consuming the 95845th data packet!
# Consuming the 95846th data packet!
# Consuming the 95847th data packet!
# Consuming the 95848th data packet!
# Consuming the 95849th data packet!
# Consuming the 95850th data packet!
# Consuming the 95851th data packet!
# Consuming the 95852th data packet!
# Consuming the 95853th data packet!
# Consuming the 95854th data packet!
# Consuming the 95855th data packet!
# Consuming the 95856th data packet!
# Consuming the 95857th data packet!
# Consuming the 95858th data packet!
# Consuming the 95859th data packet!
# Consuming the 95860th data packet!
# Consuming the 95861th data packet!
# Consuming the 95862th data packet!
# Consuming the 95863th data packet!
# Consuming the 95864th data packet!
# Consuming the 95865th data packet!
# Consuming the 95866th data packet!
# Consuming the 95867th data packet!
# Consuming the 95868th data packet!
# Consuming the 95869th data packet!
# Consuming the 95870th data packet!
# Consuming the 95871th data packet!
# Consuming the 95872th data packet!
# Consuming the 95873th data packet!
# Consuming the 95874th data packet!
# Consuming the 95875th data packet!
# Consuming the 95876th data packet!
# Consuming the 95877th data packet!
# Consuming the 95878th data packet!
# Consuming the 95879th data packet!
# Consuming the 95880th data packet!
# Consuming the 95881th data packet!
# Consuming the 95882th data packet!
# Consuming the 95883th data packet!
# Consuming the 95884th data packet!
# Consuming the 95885th data packet!
# Consuming the 95886th data packet!
# Consuming the 95887th data packet!
# Consuming the 95888th data packet!
# Consuming the 95889th data packet!
# Consuming the 95890th data packet!
# Consuming the 95891th data packet!
# Consuming the 95892th data packet!
# Consuming the 95893th data packet!
# Consuming the 95894th data packet!
# Consuming the 95895th data packet!
# Consuming the 95896th data packet!
# Consuming the 95897th data packet!
# Consuming the 95898th data packet!
# Consuming the 95899th data packet!
# Consuming the 95900th data packet!
# Consuming the 95901th data packet!
# Consuming the 95902th data packet!
# Consuming the 95903th data packet!
# Consuming the 95904th data packet!
# Consuming the 95905th data packet!
# Consuming the 95906th data packet!
# Consuming the 95907th data packet!
# Consuming the 95908th data packet!
# Consuming the 95909th data packet!
# Consuming the 95910th data packet!
# Consuming the 95911th data packet!
# Consuming the 95912th data packet!
# Consuming the 95913th data packet!
# Consuming the 95914th data packet!
# Consuming the 95915th data packet!
# Consuming the 95916th data packet!
# Consuming the 95917th data packet!
# Consuming the 95918th data packet!
# Consuming the 95919th data packet!
# Consuming the 95920th data packet!
# Consuming the 95921th data packet!
# Consuming the 95922th data packet!
# Consuming the 95923th data packet!
# Consuming the 95924th data packet!
# Consuming the 95925th data packet!
# Consuming the 95926th data packet!
# Consuming the 95927th data packet!
# Consuming the 95928th data packet!
# Consuming the 95929th data packet!
# Consuming the 95930th data packet!
# Consuming the 95931th data packet!
# Consuming the 95932th data packet!
# Consuming the 95933th data packet!
# Consuming the 95934th data packet!
# Consuming the 95935th data packet!
# Consuming the 95936th data packet!
# Consuming the 95937th data packet!
# Consuming the 95938th data packet!
# Consuming the 95939th data packet!
# Consuming the 95940th data packet!
# Consuming the 95941th data packet!
# Consuming the 95942th data packet!
# Consuming the 95943th data packet!
# Consuming the 95944th data packet!
# Consuming the 95945th data packet!
# Consuming the 95946th data packet!
# Consuming the 95947th data packet!
# Consuming the 95948th data packet!
# Consuming the 95949th data packet!
# Consuming the 95950th data packet!
# Consuming the 95951th data packet!
# Consuming the 95952th data packet!
# Consuming the 95953th data packet!
# Consuming the 95954th data packet!
# Consuming the 95955th data packet!
# Consuming the 95956th data packet!
# Consuming the 95957th data packet!
# Consuming the 95958th data packet!
# Consuming the 95959th data packet!
# Consuming the 95960th data packet!
# Consuming the 95961th data packet!
# Consuming the 95962th data packet!
# Consuming the 95963th data packet!
# Consuming the 95964th data packet!
# Consuming the 95965th data packet!
# Consuming the 95966th data packet!
# Consuming the 95967th data packet!
# Consuming the 95968th data packet!
# Consuming the 95969th data packet!
# Consuming the 95970th data packet!
# Consuming the 95971th data packet!
# Consuming the 95972th data packet!
# Consuming the 95973th data packet!
# Consuming the 95974th data packet!
# Consuming the 95975th data packet!
# Consuming the 95976th data packet!
# Consuming the 95977th data packet!
# Consuming the 95978th data packet!
# Consuming the 95979th data packet!
# Consuming the 95980th data packet!
# Consuming the 95981th data packet!
# Consuming the 95982th data packet!
# Consuming the 95983th data packet!
# Consuming the 95984th data packet!
# Consuming the 95985th data packet!
# Consuming the 95986th data packet!
# Consuming the 95987th data packet!
# Consuming the 95988th data packet!
# Consuming the 95989th data packet!
# Consuming the 95990th data packet!
# Consuming the 95991th data packet!
# Consuming the 95992th data packet!
# Consuming the 95993th data packet!
# Consuming the 95994th data packet!
# Consuming the 95995th data packet!
# Consuming the 95996th data packet!
# Consuming the 95997th data packet!
# Consuming the 95998th data packet!
# Consuming the 95999th data packet!
# Consuming the 96000th data packet!
# Consuming the 96001th data packet!
# Consuming the 96002th data packet!
# Consuming the 96003th data packet!
# Consuming the 96004th data packet!
# Consuming the 96005th data packet!
# Consuming the 96006th data packet!
# Consuming the 96007th data packet!
# Consuming the 96008th data packet!
# Consuming the 96009th data packet!
# Consuming the 96010th data packet!
# Consuming the 96011th data packet!
# Consuming the 96012th data packet!
# Consuming the 96013th data packet!
# Consuming the 96014th data packet!
# Consuming the 96015th data packet!
# Consuming the 96016th data packet!
# Consuming the 96017th data packet!
# Consuming the 96018th data packet!
# Consuming the 96019th data packet!
# Consuming the 96020th data packet!
# Consuming the 96021th data packet!
# Consuming the 96022th data packet!
# Consuming the 96023th data packet!
# Consuming the 96024th data packet!
# Consuming the 96025th data packet!
# Consuming the 96026th data packet!
# Consuming the 96027th data packet!
# Consuming the 96028th data packet!
# Consuming the 96029th data packet!
# Consuming the 96030th data packet!
# Consuming the 96031th data packet!
# Consuming the 96032th data packet!
# Consuming the 96033th data packet!
# Consuming the 96034th data packet!
# Consuming the 96035th data packet!
# Consuming the 96036th data packet!
# Consuming the 96037th data packet!
# Consuming the 96038th data packet!
# Consuming the 96039th data packet!
# Consuming the 96040th data packet!
# Consuming the 96041th data packet!
# Consuming the 96042th data packet!
# Consuming the 96043th data packet!
# Consuming the 96044th data packet!
# Consuming the 96045th data packet!
# Consuming the 96046th data packet!
# Consuming the 96047th data packet!
# Consuming the 96048th data packet!
# Consuming the 96049th data packet!
# Consuming the 96050th data packet!
# Consuming the 96051th data packet!
# Consuming the 96052th data packet!
# Consuming the 96053th data packet!
# Consuming the 96054th data packet!
# Consuming the 96055th data packet!
# Consuming the 96056th data packet!
# Consuming the 96057th data packet!
# Consuming the 96058th data packet!
# Consuming the 96059th data packet!
# Consuming the 96060th data packet!
# Consuming the 96061th data packet!
# Consuming the 96062th data packet!
# Consuming the 96063th data packet!
# Consuming the 96064th data packet!
# Consuming the 96065th data packet!
# Consuming the 96066th data packet!
# Consuming the 96067th data packet!
# Consuming the 96068th data packet!
# Consuming the 96069th data packet!
# Consuming the 96070th data packet!
# Consuming the 96071th data packet!
# Consuming the 96072th data packet!
# Consuming the 96073th data packet!
# Consuming the 96074th data packet!
# Consuming the 96075th data packet!
# Consuming the 96076th data packet!
# Consuming the 96077th data packet!
# Consuming the 96078th data packet!
# Consuming the 96079th data packet!
# Consuming the 96080th data packet!
# Consuming the 96081th data packet!
# Consuming the 96082th data packet!
# Consuming the 96083th data packet!
# Consuming the 96084th data packet!
# Consuming the 96085th data packet!
# Consuming the 96086th data packet!
# Consuming the 96087th data packet!
# Consuming the 96088th data packet!
# Consuming the 96089th data packet!
# Consuming the 96090th data packet!
# Consuming the 96091th data packet!
# Consuming the 96092th data packet!
# Consuming the 96093th data packet!
# Consuming the 96094th data packet!
# Consuming the 96095th data packet!
# Consuming the 96096th data packet!
# Consuming the 96097th data packet!
# Consuming the 96098th data packet!
# Consuming the 96099th data packet!
# Consuming the 96100th data packet!
# Consuming the 96101th data packet!
# Consuming the 96102th data packet!
# Consuming the 96103th data packet!
# Consuming the 96104th data packet!
# Consuming the 96105th data packet!
# Consuming the 96106th data packet!
# Consuming the 96107th data packet!
# Consuming the 96108th data packet!
# Consuming the 96109th data packet!
# Consuming the 96110th data packet!
# Consuming the 96111th data packet!
# Consuming the 96112th data packet!
# Consuming the 96113th data packet!
# Consuming the 96114th data packet!
# Consuming the 96115th data packet!
# Consuming the 96116th data packet!
# Consuming the 96117th data packet!
# Consuming the 96118th data packet!
# Consuming the 96119th data packet!
# Consuming the 96120th data packet!
# Consuming the 96121th data packet!
# Consuming the 96122th data packet!
# Consuming the 96123th data packet!
# Consuming the 96124th data packet!
# Consuming the 96125th data packet!
# Consuming the 96126th data packet!
# Consuming the 96127th data packet!
# Consuming the 96128th data packet!
# Consuming the 96129th data packet!
# Consuming the 96130th data packet!
# Consuming the 96131th data packet!
# Consuming the 96132th data packet!
# Consuming the 96133th data packet!
# Consuming the 96134th data packet!
# Consuming the 96135th data packet!
# Consuming the 96136th data packet!
# Consuming the 96137th data packet!
# Consuming the 96138th data packet!
# Consuming the 96139th data packet!
# Consuming the 96140th data packet!
# Consuming the 96141th data packet!
# Consuming the 96142th data packet!
# Consuming the 96143th data packet!
# Consuming the 96144th data packet!
# Consuming the 96145th data packet!
# Consuming the 96146th data packet!
# Consuming the 96147th data packet!
# Consuming the 96148th data packet!
# Consuming the 96149th data packet!
# Consuming the 96150th data packet!
# Consuming the 96151th data packet!
# Consuming the 96152th data packet!
# Consuming the 96153th data packet!
# Consuming the 96154th data packet!
# Consuming the 96155th data packet!
# Consuming the 96156th data packet!
# Consuming the 96157th data packet!
# Consuming the 96158th data packet!
# Consuming the 96159th data packet!
# Consuming the 96160th data packet!
# Consuming the 96161th data packet!
# Consuming the 96162th data packet!
# Consuming the 96163th data packet!
# Consuming the 96164th data packet!
# Consuming the 96165th data packet!
# Consuming the 96166th data packet!
# Consuming the 96167th data packet!
# Consuming the 96168th data packet!
# Consuming the 96169th data packet!
# Consuming the 96170th data packet!
# Consuming the 96171th data packet!
# Consuming the 96172th data packet!
# Consuming the 96173th data packet!
# Consuming the 96174th data packet!
# Consuming the 96175th data packet!
# Consuming the 96176th data packet!
# Consuming the 96177th data packet!
# Consuming the 96178th data packet!
# Consuming the 96179th data packet!
# Consuming the 96180th data packet!
# Consuming the 96181th data packet!
# Consuming the 96182th data packet!
# Consuming the 96183th data packet!
# Consuming the 96184th data packet!
# Consuming the 96185th data packet!
# Consuming the 96186th data packet!
# Consuming the 96187th data packet!
# Consuming the 96188th data packet!
# Consuming the 96189th data packet!
# Consuming the 96190th data packet!
# Consuming the 96191th data packet!
# Consuming the 96192th data packet!
# Consuming the 96193th data packet!
# Consuming the 96194th data packet!
# Consuming the 96195th data packet!
# Consuming the 96196th data packet!
# Consuming the 96197th data packet!
# Consuming the 96198th data packet!
# Consuming the 96199th data packet!
# Consuming the 96200th data packet!
# Consuming the 96201th data packet!
# Consuming the 96202th data packet!
# Consuming the 96203th data packet!
# Consuming the 96204th data packet!
# Consuming the 96205th data packet!
# Consuming the 96206th data packet!
# Consuming the 96207th data packet!
# Consuming the 96208th data packet!
# Consuming the 96209th data packet!
# Consuming the 96210th data packet!
# Consuming the 96211th data packet!
# Consuming the 96212th data packet!
# Consuming the 96213th data packet!
# Consuming the 96214th data packet!
# Consuming the 96215th data packet!
# Consuming the 96216th data packet!
# Consuming the 96217th data packet!
# Consuming the 96218th data packet!
# Consuming the 96219th data packet!
# Consuming the 96220th data packet!
# Consuming the 96221th data packet!
# Consuming the 96222th data packet!
# Consuming the 96223th data packet!
# Consuming the 96224th data packet!
# Consuming the 96225th data packet!
# Consuming the 96226th data packet!
# Consuming the 96227th data packet!
# Consuming the 96228th data packet!
# Consuming the 96229th data packet!
# Consuming the 96230th data packet!
# Consuming the 96231th data packet!
# Consuming the 96232th data packet!
# Consuming the 96233th data packet!
# Consuming the 96234th data packet!
# Consuming the 96235th data packet!
# Consuming the 96236th data packet!
# Consuming the 96237th data packet!
# Consuming the 96238th data packet!
# Consuming the 96239th data packet!
# Consuming the 96240th data packet!
# Consuming the 96241th data packet!
# Consuming the 96242th data packet!
# Consuming the 96243th data packet!
# Consuming the 96244th data packet!
# Consuming the 96245th data packet!
# Consuming the 96246th data packet!
# Consuming the 96247th data packet!
# Consuming the 96248th data packet!
# Consuming the 96249th data packet!
# Consuming the 96250th data packet!
# Consuming the 96251th data packet!
# Consuming the 96252th data packet!
# Consuming the 96253th data packet!
# Consuming the 96254th data packet!
# Consuming the 96255th data packet!
# Consuming the 96256th data packet!
# Consuming the 96257th data packet!
# Consuming the 96258th data packet!
# Consuming the 96259th data packet!
# Consuming the 96260th data packet!
# Consuming the 96261th data packet!
# Consuming the 96262th data packet!
# Consuming the 96263th data packet!
# Consuming the 96264th data packet!
# Consuming the 96265th data packet!
# Consuming the 96266th data packet!
# Consuming the 96267th data packet!
# Consuming the 96268th data packet!
# Consuming the 96269th data packet!
# Consuming the 96270th data packet!
# Consuming the 96271th data packet!
# Consuming the 96272th data packet!
# Consuming the 96273th data packet!
# Consuming the 96274th data packet!
# Consuming the 96275th data packet!
# Consuming the 96276th data packet!
# Consuming the 96277th data packet!
# Consuming the 96278th data packet!
# Consuming the 96279th data packet!
# Consuming the 96280th data packet!
# Consuming the 96281th data packet!
# Consuming the 96282th data packet!
# Consuming the 96283th data packet!
# Consuming the 96284th data packet!
# Consuming the 96285th data packet!
# Consuming the 96286th data packet!
# Consuming the 96287th data packet!
# Consuming the 96288th data packet!
# Consuming the 96289th data packet!
# Consuming the 96290th data packet!
# Consuming the 96291th data packet!
# Consuming the 96292th data packet!
# Consuming the 96293th data packet!
# Consuming the 96294th data packet!
# Consuming the 96295th data packet!
# Consuming the 96296th data packet!
# Consuming the 96297th data packet!
# Consuming the 96298th data packet!
# Consuming the 96299th data packet!
# Consuming the 96300th data packet!
# Consuming the 96301th data packet!
# Consuming the 96302th data packet!
# Consuming the 96303th data packet!
# Consuming the 96304th data packet!
# Consuming the 96305th data packet!
# Consuming the 96306th data packet!
# Consuming the 96307th data packet!
# Consuming the 96308th data packet!
# Consuming the 96309th data packet!
# Consuming the 96310th data packet!
# Consuming the 96311th data packet!
# Consuming the 96312th data packet!
# Consuming the 96313th data packet!
# Consuming the 96314th data packet!
# Consuming the 96315th data packet!
# Consuming the 96316th data packet!
# Consuming the 96317th data packet!
# Consuming the 96318th data packet!
# Consuming the 96319th data packet!
# Consuming the 96320th data packet!
# Consuming the 96321th data packet!
# Consuming the 96322th data packet!
# Consuming the 96323th data packet!
# Consuming the 96324th data packet!
# Consuming the 96325th data packet!
# Consuming the 96326th data packet!
# Consuming the 96327th data packet!
# Consuming the 96328th data packet!
# Consuming the 96329th data packet!
# Consuming the 96330th data packet!
# Consuming the 96331th data packet!
# Consuming the 96332th data packet!
# Consuming the 96333th data packet!
# Consuming the 96334th data packet!
# Consuming the 96335th data packet!
# Consuming the 96336th data packet!
# Consuming the 96337th data packet!
# Consuming the 96338th data packet!
# Consuming the 96339th data packet!
# Consuming the 96340th data packet!
# Consuming the 96341th data packet!
# Consuming the 96342th data packet!
# Consuming the 96343th data packet!
# Consuming the 96344th data packet!
# Consuming the 96345th data packet!
# Consuming the 96346th data packet!
# Consuming the 96347th data packet!
# Consuming the 96348th data packet!
# Consuming the 96349th data packet!
# Consuming the 96350th data packet!
# Consuming the 96351th data packet!
# Consuming the 96352th data packet!
# Consuming the 96353th data packet!
# Consuming the 96354th data packet!
# Consuming the 96355th data packet!
# Consuming the 96356th data packet!
# Consuming the 96357th data packet!
# Consuming the 96358th data packet!
# Consuming the 96359th data packet!
# Consuming the 96360th data packet!
# Consuming the 96361th data packet!
# Consuming the 96362th data packet!
# Consuming the 96363th data packet!
# Consuming the 96364th data packet!
# Consuming the 96365th data packet!
# Consuming the 96366th data packet!
# Consuming the 96367th data packet!
# Consuming the 96368th data packet!
# Consuming the 96369th data packet!
# Consuming the 96370th data packet!
# Consuming the 96371th data packet!
# Consuming the 96372th data packet!
# Consuming the 96373th data packet!
# Consuming the 96374th data packet!
# Consuming the 96375th data packet!
# Consuming the 96376th data packet!
# Consuming the 96377th data packet!
# ...
# Consuming the 99545th data packet!
# Consuming the 99546th data packet!
# Consuming the 99547th data packet!
# Consuming the 99548th data packet!
# Consuming the 99549th data packet!
# Consuming the 99550th data packet!
# Consuming the 99551th data packet!
# Consuming the 99552th data packet!
# Consuming the 99553th data packet!
# Consuming the 99554th data packet!
# Consuming the 99555th data packet!
# Consuming the 99556th data packet!
# Consuming the 99557th data packet!
# Consuming the 99558th data packet!
# Consuming the 99559th data packet!
# Consuming the 99560th data packet!
# Consuming the 99561th data packet!
# Consuming the 99562th data packet!
# Consuming the 99563th data packet!
# Consuming the 99564th data packet!
# Consuming the 99565th data packet!
# Consuming the 99566th data packet!
# Consuming the 99567th data packet!
# Consuming the 99568th data packet!
# Consuming the 99569th data packet!
# Consuming the 99570th data packet!
# Consuming the 99571th data packet!
# Consuming the 99572th data packet!
# Consuming the 99573th data packet!
# Consuming the 99574th data packet!
# Consuming the 99575th data packet!
# Consuming the 99576th data packet!
# Consuming the 99577th data packet!
# Consuming the 99578th data packet!
# Consuming the 99579th data packet!
# Consuming the 99580th data packet!
# Consuming the 99581th data packet!
# Consuming the 99582th data packet!
# Consuming the 99583th data packet!
# Consuming the 99584th data packet!
# Consuming the 99585th data packet!
# Consuming the 99586th data packet!
# Consuming the 99587th data packet!
# Consuming the 99588th data packet!
# Consuming the 99589th data packet!
# Consuming the 99590th data packet!
# Consuming the 99591th data packet!
# Consuming the 99592th data packet!
# Consuming the 99593th data packet!
# Consuming the 99594th data packet!
# Consuming the 99595th data packet!
# Consuming the 99596th data packet!
# Consuming the 99597th data packet!
# Consuming the 99598th data packet!
# Consuming the 99599th data packet!
# Consuming the 99600th data packet!
# Consuming the 99601th data packet!
# Consuming the 99602th data packet!
# Consuming the 99603th data packet!
# Consuming the 99604th data packet!
# Consuming the 99605th data packet!
# Consuming the 99606th data packet!
# Consuming the 99607th data packet!
# Consuming the 99608th data packet!
# Consuming the 99609th data packet!
# Consuming the 99610th data packet!
# Consuming the 99611th data packet!
# Consuming the 99612th data packet!
# Consuming the 99613th data packet!
# Consuming the 99614th data packet!
# Consuming the 99615th data packet!
# Consuming the 99616th data packet!
# Consuming the 99617th data packet!
# Consuming the 99618th data packet!
# Consuming the 99619th data packet!
# Consuming the 99620th data packet!
# Consuming the 99621th data packet!
# Consuming the 99622th data packet!
# Consuming the 99623th data packet!
# Consuming the 99624th data packet!
# Consuming the 99625th data packet!
# Consuming the 99626th data packet!
# Consuming the 99627th data packet!
# Consuming the 99628th data packet!
# Consuming the 99629th data packet!
# Consuming the 99630th data packet!
# Consuming the 99631th data packet!
# Consuming the 99632th data packet!
# Consuming the 99633th data packet!
# Consuming the 99634th data packet!
# Consuming the 99635th data packet!
# Consuming the 99636th data packet!
# Consuming the 99637th data packet!
# Consuming the 99638th data packet!
# Consuming the 99639th data packet!
# Consuming the 99640th data packet!
# Consuming the 99641th data packet!
# Consuming the 99642th data packet!
# Consuming the 99643th data packet!
# Consuming the 99644th data packet!
# Consuming the 99645th data packet!
# Consuming the 99646th data packet!
# Consuming the 99647th data packet!
# Consuming the 99648th data packet!
# Consuming the 99649th data packet!
# Consuming the 99650th data packet!
# Consuming the 99651th data packet!
# Consuming the 99652th data packet!
# Consuming the 99653th data packet!
# Consuming the 99654th data packet!
# Consuming the 99655th data packet!
# Consuming the 99656th data packet!
# Consuming the 99657th data packet!
# Consuming the 99658th data packet!
# Consuming the 99659th data packet!
# Consuming the 99660th data packet!
# Consuming the 99661th data packet!
# Consuming the 99662th data packet!
# Consuming the 99663th data packet!
# Consuming the 99664th data packet!
# Consuming the 99665th data packet!
# Consuming the 99666th data packet!
# Consuming the 99667th data packet!
# Consuming the 99668th data packet!
# Consuming the 99669th data packet!
# Consuming the 99670th data packet!
# Consuming the 99671th data packet!
# Consuming the 99672th data packet!
# Consuming the 99673th data packet!
# Consuming the 99674th data packet!
# Consuming the 99675th data packet!
# Consuming the 99676th data packet!
# Consuming the 99677th data packet!
# Consuming the 99678th data packet!
# Consuming the 99679th data packet!
# Consuming the 99680th data packet!
# Consuming the 99681th data packet!
# Consuming the 99682th data packet!
# Consuming the 99683th data packet!
# Consuming the 99684th data packet!
# Consuming the 99685th data packet!
# Consuming the 99686th data packet!
# Consuming the 99687th data packet!
# Consuming the 99688th data packet!
# Consuming the 99689th data packet!
# Consuming the 99690th data packet!
# Consuming the 99691th data packet!
# Consuming the 99692th data packet!
# Consuming the 99693th data packet!
# Consuming the 99694th data packet!
# Consuming the 99695th data packet!
# Consuming the 99696th data packet!
# Consuming the 99697th data packet!
# Consuming the 99698th data packet!
# Consuming the 99699th data packet!
# Consuming the 99700th data packet!
# Consuming the 99701th data packet!
# Consuming the 99702th data packet!
# Consuming the 99703th data packet!
# Consuming the 99704th data packet!
# Consuming the 99705th data packet!
# Consuming the 99706th data packet!
# Consuming the 99707th data packet!
# Consuming the 99708th data packet!
# Consuming the 99709th data packet!
# Consuming the 99710th data packet!
# Consuming the 99711th data packet!
# Consuming the 99712th data packet!
# Consuming the 99713th data packet!
# Consuming the 99714th data packet!
# Consuming the 99715th data packet!
# Consuming the 99716th data packet!
# Consuming the 99717th data packet!
# Consuming the 99718th data packet!
# Consuming the 99719th data packet!
# Consuming the 99720th data packet!
# Consuming the 99721th data packet!
# Consuming the 99722th data packet!
# Consuming the 99723th data packet!
# Consuming the 99724th data packet!
# Consuming the 99725th data packet!
# Consuming the 99726th data packet!
# Consuming the 99727th data packet!
# Consuming the 99728th data packet!
# Consuming the 99729th data packet!
# Consuming the 99730th data packet!
# Consuming the 99731th data packet!
# Consuming the 99732th data packet!
# Consuming the 99733th data packet!
# Consuming the 99734th data packet!
# Consuming the 99735th data packet!
# Consuming the 99736th data packet!
# Consuming the 99737th data packet!
# Consuming the 99738th data packet!
# Consuming the 99739th data packet!
# Consuming the 99740th data packet!
# Consuming the 99741th data packet!
# Consuming the 99742th data packet!
# Consuming the 99743th data packet!
# Consuming the 99744th data packet!
# Consuming the 99745th data packet!
# Consuming the 99746th data packet!
# Consuming the 99747th data packet!
# Consuming the 99748th data packet!
# Consuming the 99749th data packet!
# Consuming the 99750th data packet!
# Consuming the 99751th data packet!
# Consuming the 99752th data packet!
# Consuming the 99753th data packet!
# Consuming the 99754th data packet!
# Consuming the 99755th data packet!
# Consuming the 99756th data packet!
# Consuming the 99757th data packet!
# Consuming the 99758th data packet!
# Consuming the 99759th data packet!
# Consuming the 99760th data packet!
# Consuming the 99761th data packet!
# Consuming the 99762th data packet!
# Consuming the 99763th data packet!
# Consuming the 99764th data packet!
# Consuming the 99765th data packet!
# Consuming the 99766th data packet!
# Consuming the 99767th data packet!
# Consuming the 99768th data packet!
# Consuming the 99769th data packet!
# Consuming the 99770th data packet!
# Consuming the 99771th data packet!
# Consuming the 99772th data packet!
# Consuming the 99773th data packet!
# Consuming the 99774th data packet!
# Consuming the 99775th data packet!
# Consuming the 99776th data packet!
# Consuming the 99777th data packet!
# Consuming the 99778th data packet!
# Consuming the 99779th data packet!
# Consuming the 99780th data packet!
# Consuming the 99781th data packet!
# Consuming the 99782th data packet!
# Consuming the 99783th data packet!
# Consuming the 99784th data packet!
# Consuming the 99785th data packet!
# Consuming the 99786th data packet!
# Consuming the 99787th data packet!
# Consuming the 99788th data packet!
# Consuming the 99789th data packet!
# Consuming the 99790th data packet!
# Consuming the 99791th data packet!
# Consuming the 99792th data packet!
# Consuming the 99793th data packet!
# Consuming the 99794th data packet!
# Consuming the 99795th data packet!
# Consuming the 99796th data packet!
# Consuming the 99797th data packet!
# Consuming the 99798th data packet!
# Consuming the 99799th data packet!
# Consuming the 99800th data packet!
# Consuming the 99801th data packet!
# Consuming the 99802th data packet!
# Consuming the 99803th data packet!
# Consuming the 99804th data packet!
# Consuming the 99805th data packet!
# Consuming the 99806th data packet!
# Consuming the 99807th data packet!
# Consuming the 99808th data packet!
# Consuming the 99809th data packet!
# Consuming the 99810th data packet!
# Consuming the 99811th data packet!
# Consuming the 99812th data packet!
# Consuming the 99813th data packet!
# Consuming the 99814th data packet!
# Consuming the 99815th data packet!
# Consuming the 99816th data packet!
# Consuming the 99817th data packet!
# Consuming the 99818th data packet!
# Consuming the 99819th data packet!
# Consuming the 99820th data packet!
# Consuming the 99821th data packet!
# Consuming the 99822th data packet!
# Consuming the 99823th data packet!
# Consuming the 99824th data packet!
# Consuming the 99825th data packet!
# Consuming the 99826th data packet!
# Consuming the 99827th data packet!
# Consuming the 99828th data packet!
# Consuming the 99829th data packet!
# Consuming the 99830th data packet!
# Consuming the 99831th data packet!
# Consuming the 99832th data packet!
# Consuming the 99833th data packet!
# Consuming the 99834th data packet!
# Consuming the 99835th data packet!
# Consuming the 99836th data packet!
# Consuming the 99837th data packet!
# Consuming the 99838th data packet!
# Consuming the 99839th data packet!
# Consuming the 99840th data packet!
# Consuming the 99841th data packet!
# Consuming the 99842th data packet!
# Consuming the 99843th data packet!
# Consuming the 99844th data packet!
# Consuming the 99845th data packet!
# Consuming the 99846th data packet!
# Consuming the 99847th data packet!
# Consuming the 99848th data packet!
# Consuming the 99849th data packet!
# Consuming the 99850th data packet!
# Consuming the 99851th data packet!
# Consuming the 99852th data packet!
# Consuming the 99853th data packet!
# Consuming the 99854th data packet!
# Consuming the 99855th data packet!
# Consuming the 99856th data packet!
# Consuming the 99857th data packet!
# Consuming the 99858th data packet!
# Consuming the 99859th data packet!
# Consuming the 99860th data packet!
# Consuming the 99861th data packet!
# Consuming the 99862th data packet!
# Consuming the 99863th data packet!
# Consuming the 99864th data packet!
# Consuming the 99865th data packet!
# Consuming the 99866th data packet!
# Consuming the 99867th data packet!
# Consuming the 99868th data packet!
# Consuming the 99869th data packet!
# Consuming the 99870th data packet!
# Consuming the 99871th data packet!
# Consuming the 99872th data packet!
# Consuming the 99873th data packet!
# Consuming the 99874th data packet!
# Consuming the 99875th data packet!
# Consuming the 99876th data packet!
# Consuming the 99877th data packet!
# Consuming the 99878th data packet!
# Consuming the 99879th data packet!
# Consuming the 99880th data packet!
# Consuming the 99881th data packet!
# Consuming the 99882th data packet!
# Consuming the 99883th data packet!
# Consuming the 99884th data packet!
# Consuming the 99885th data packet!
# Consuming the 99886th data packet!
# Consuming the 99887th data packet!
# Consuming the 99888th data packet!
# Consuming the 99889th data packet!
# Consuming the 99890th data packet!
# Consuming the 99891th data packet!
# Consuming the 99892th data packet!
# Consuming the 99893th data packet!
# Consuming the 99894th data packet!
# Consuming the 99895th data packet!
# Consuming the 99896th data packet!
# Consuming the 99897th data packet!
# Consuming the 99898th data packet!
# Consuming the 99899th data packet!
# Consuming the 99900th data packet!
# Consuming the 99901th data packet!
# Consuming the 99902th data packet!
# Consuming the 99903th data packet!
# Consuming the 99904th data packet!
# Consuming the 99905th data packet!
# Consuming the 99906th data packet!
# Consuming the 99907th data packet!
# Consuming the 99908th data packet!
# Consuming the 99909th data packet!
# Consuming the 99910th data packet!
# Consuming the 99911th data packet!
# Consuming the 99912th data packet!
# Consuming the 99913th data packet!
# Consuming the 99914th data packet!
# Consuming the 99915th data packet!
# Consuming the 99916th data packet!
# Consuming the 99917th data packet!
# Consuming the 99918th data packet!
# Consuming the 99919th data packet!
# Consuming the 99920th data packet!
# Consuming the 99921th data packet!
# Consuming the 99922th data packet!
# Consuming the 99923th data packet!
# Consuming the 99924th data packet!
# Consuming the 99925th data packet!
# Consuming the 99926th data packet!
# Consuming the 99927th data packet!
# Consuming the 99928th data packet!
# Consuming the 99929th data packet!
# Consuming the 99930th data packet!
# Consuming the 99931th data packet!
# Consuming the 99932th data packet!
# Consuming the 99933th data packet!
# Consuming the 99934th data packet!
# Consuming the 99935th data packet!
# Consuming the 99936th data packet!
# Consuming the 99937th data packet!
# Consuming the 99938th data packet!
# Consuming the 99939th data packet!
# Consuming the 99940th data packet!
# Consuming the 99941th data packet!
# Consuming the 99942th data packet!
# Consuming the 99943th data packet!
# Consuming the 99944th data packet!
# Consuming the 99945th data packet!
# Consuming the 99946th data packet!
# Consuming the 99947th data packet!
# Consuming the 99948th data packet!
# Consuming the 99949th data packet!
# Consuming the 99950th data packet!
# Consuming the 99951th data packet!
# Consuming the 99952th data packet!
# Consuming the 99953th data packet!
# Consuming the 99954th data packet!
# Consuming the 99955th data packet!
# Consuming the 99956th data packet!
# Consuming the 99957th data packet!
# Consuming the 99958th data packet!
# Consuming the 99959th data packet!
# Consuming the 99960th data packet!
# Consuming the 99961th data packet!
# Consuming the 99962th data packet!
# Consuming the 99963th data packet!
# Consuming the 99964th data packet!
# Consuming the 99965th data packet!
# Consuming the 99966th data packet!
# Consuming the 99967th data packet!
# Consuming the 99968th data packet!
# Consuming the 99969th data packet!
# Consuming the 99970th data packet!
# Consuming the 99971th data packet!
# Consuming the 99972th data packet!
# Consuming the 99973th data packet!
# Consuming the 99974th data packet!
# Consuming the 99975th data packet!
# Consuming the 99976th data packet!
# Consuming the 99977th data packet!
# Consuming the 99978th data packet!
# Consuming the 99979th data packet!
# Consuming the 99980th data packet!
# Consuming the 99981th data packet!
# Consuming the 99982th data packet!
# Consuming the 99983th data packet!
# Consuming the 99984th data packet!
# Consuming the 99985th data packet!
# Consuming the 99986th data packet!
# Consuming the 99987th data packet!
# Consuming the 99988th data packet!
# Consuming the 99989th data packet!
# Consuming the 99990th data packet!
# Consuming the 99991th data packet!
# Consuming the 99992th data packet!
# Consuming the 99993th data packet!
# Consuming the 99994th data packet!
# Consuming the 99995th data packet!
# Consuming the 99996th data packet!
# Consuming the 99997th data packet!
# Consuming the 99998th data packet!
# Consuming the 99999th data packet!
# Consuming the 100000th data packet!
# Consuming the 100001th data packet!

# %%
ts=pd.DataFrame(dat)

# %%
ts
# Out:
#        Destination Port  Flow Duration  ...  Idle Min   Label
# 0                    53          30973  ...         0  BENIGN
# 1                 52996             71  ...         0  BENIGN
# 2                    53          77249  ...         0  BENIGN
# 3                    53            223  ...         0  BENIGN
# 4                    53            152  ...         0  BENIGN
# ...                 ...            ...  ...       ...     ...
# 99995                53          74545  ...         0  BENIGN
# 99996                53            159  ...         0  BENIGN
# 99997                80        5700452  ...         0  BENIGN
# 99998             41886          14357  ...         0  BENIGN
# 99999                53         989770  ...         0  BENIGN
#
# [100000 rows x 79 columns]

# %%
df
# Out:
#        Destination Port  Flow Duration  ...  Idle Min  Label
# 0                    53            159  ...         0      1
# 1                    53          51673  ...         0      1
# 2                  7496             43  ...         0      2
# 3                 46564             61  ...         0      1
# 4                    80             69  ...         0      1
# ...                 ...            ...  ...       ...    ...
# 25186             50100            197  ...         0      1
# 25187              3390             48  ...         0      2
# 25188               123            117  ...         0      1
# 25189               443      116260101  ...   5201068      1
# 25190               443        1334422  ...         0      1
#
# [25191 rows x 79 columns]

# %%
ts.shape
# Out:
# (100000, 79)

# %% [markdown]
# replace nan with zero

# %%
ts = ts.fillna(0)

# %%
print(len(ts))
# Out:
# 100000

# %%
ts.isnull().sum().max()
# Out:
# 0

# %% [markdown]
# use label encodel to convert to numeric like we make on static

# %%
import category_encoders as ce


# encode categorical variables with ordinal encoding

encoder = ce.OrdinalEncoder(cols=['Label'])


ts = encoder.fit_transform(ts)

# %%
from sklearn.model_selection import train_test_split


#X = df.drop(['Fwd PSH Flags','Bwd PSH Flags','Fwd URG Flags','Bwd URG Flags','Label'],axis=1)
Xt = ts.drop(['Label'],axis=1)
yt =ts['Label']

# %% [markdown]
# #use first classfier random forest to predict on the model to predict on all 100000 it give me better result with randomforst .99 accuracy

# %%
y_pred2 = rfc.predict(Xt)

from sklearn.metrics import accuracy_score

# Check accuracy score 

print('Model accuracy score with doors variable removed : {0:0.4f}'. format(accuracy_score(yt, y_pred2)))
# Out:
# Model accuracy score with doors variable removed : 0.9962

# %% [markdown]
# when use the first model rondomforest which trained on static use it to predict
# 100000 records

# %%
# Print the Confusion Matrix and slice it into four pieces

from sklearn.metrics import confusion_matrix

cm = confusion_matrix(yt, y_pred2)

print('Confusion matrix\n\n', cm)
# Out:
# Confusion matrix
#
#  [[90103    64]
#  [  316  9517]]

# %%
from sklearn.metrics import classification_report

print(classification_report(yt, y_pred2))
# Out:
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00     90167
#            2       0.99      0.97      0.98      9833
#
#     accuracy                           1.00    100000
#    macro avg       0.99      0.98      0.99    100000
# weighted avg       1.00      1.00      1.00    100000

# %% [markdown]
# #when use second mlp on 100 000

# %%
y_pred3 = clf.predict(Xt.values)

from sklearn.metrics import accuracy_score

# Check accuracy score 

print('Model accuracy score with doors variable removed : {0:0.4f}'. format(accuracy_score(yt, y_pred3)))
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:446: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# Model accuracy score with doors variable removed : 0.9506

# %%
from sklearn.metrics import classification_report

print(classification_report(yt, y_pred3))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.97      0.97      0.97     90167
#            2       0.76      0.73      0.74      9833
#
#     accuracy                           0.95    100000
#    macro avg       0.86      0.85      0.86    100000
# weighted avg       0.95      0.95      0.95    100000

# %% [markdown]
# when predict on 100000 records we get higher accuracy also on rondomforest but less on mlp

# %% [markdown]
# #predict on every 1000 instead of 100000

# %%
import category_encoders as ce
from sklearn.metrics import f1_score
from sklearn.metrics import accuracy_score

# %% [markdown]
# 1_Try to make to see what the model do with every 1000 of the records 100000
# with 1000*i)-1000:(1000*i
#  in the first iteration take 0*1000 -1000  then repeate to take the second 1000
#
#  then the model on stake data will predict on it
#
#  2_then make list to append 25000 every iteration drop 1000 from it then  take 1000 record the above to it
#  so100 iteration

# %%
lists=[]
accuracy1=[]
f1score1=[]
for i in range(1,100):
  X22 = ts[(1000*i)-1000:(1000*i)].drop(['Label'],axis=1)
  y22 = ts[(1000*i)-1000:(1000*i)]['Label']
  y_pred33 = rfc.predict(X22)
  encoder = ce.OrdinalEncoder()


  y_pred33 = encoder.fit_transform(y_pred33)
  accuracy1.append(accuracy_score(y22, y_pred33))
  f1score1.append(f1_score(y22, y_pred33, average='weighted'))
  
  
  #take the 1000 record from the data
  df.drop(df.head(1000).index, inplace=True)
  #then replace it with 1000 from kafka
  #in the first iteration take 0*1000 -1000 
  df=df.append(ts[(1000*i)-1000:(1000*i)],ignore_index=True)
  Window=df.copy()
  #print(len(df))
  #lists.append(Window)
  lists.append(df)

# %%
m_dict = {'Accuarcy1': accuracy1, 'f1score1': f1score1}
dfv1 = pd.DataFrame(m_dict)

# %%
dfv1
# Out:
#     Accuarcy1  f1score1
# 0       0.997  0.996977
# 1       0.997  0.996993
# 2       0.997  0.996979
# 3       0.993  0.992953
# 4       0.998  0.997989
# ..        ...       ...
# 94      0.996  0.995982
# 95      0.997  0.996993
# 96      0.989  0.988813
# 97      0.997  0.996980
# 98      0.997  0.996981
#
# [99 rows x 2 columns]

# %% [markdown]
# #plot accuracy score xis be the index
# and and y is the accuracy

# %%
import matplotlib.pyplot as plt
import pandas as pd
ax=plt.gca()
dfv1.reset_index().plot(kind='line',x='index',y='Accuarcy1',ax=ax)
#dfv1.reset_index().plot(kind='line',x='index',y='f1score1',ax=ax)
plt.title("accuracy graph")
# Out:
# Text(0.5, 1.0, 'accuracy graph')

# %%
import matplotlib.pyplot as plt
import pandas as pd
ax=plt.gca()
#dfv1.reset_index().plot(kind='line',x='index',y='Accuarcy1',ax=ax)
dfv1.reset_index().plot(kind='line',x='index',y='f1score1',ax=ax)
plt.title("accuracy graph")
# Out:
# Text(0.5, 1.0, 'accuracy graph')

# %% [markdown]
# ################################################################################

# %%
#window remove 1000 record from the past  static data then put 1000 record from streaming

lists=[]
for i in range(1,100):
  #take the 1000 record from the data
  df.drop(df.head(1000).index, inplace=True)
  #then replace it with 1000 from kafka
  #in the first iteration take 0*1000 -1000 
  df=df.append(ts[(1000*i)-1000:(1000*i)],ignore_index=True)
  Window=df.copy()
  print(len(df))
  #lists.append(Window)
  lists.append(df)
# Out:
# 25191
# 25191
# 25191
# 25191
# 25191
# 25191
# 25191
# 25191
# 25191
# 25191
# 25191
# 25191
# 25191
# 25191
# 25191
# 25191
# 25191
# 25191
# 25191
# 25191
# 25191
# 25191
# 25191
# 25191
# 25191
# 25191
# 25191
# 25191
# 25191
# 25191
# 25191
# 25191
# 25191
# 25191
# 25191
# 25191
# 25191
# 25191
# 25191
# 25191
# 25191
# 25191
# 25191
# 25191
# 25191
# 25191
# 25191
# 25191
# 25191
# 25191
# 25191
# 25191
# 25191
# 25191
# 25191
# 25191
# 25191
# 25191
# 25191
# 25191
# 25191
# 25191
# 25191
# 25191
# 25191
# 25191
# 25191
# 25191
# 25191
# 25191
# 25191
# 25191
# 25191
# 25191
# 25191
# 25191
# 25191
# 25191
# 25191
# 25191
# 25191
# 25191
# 25191
# 25191
# 25191
# 25191
# 25191
# 25191
# 25191
# 25191
# 25191
# 25191
# 25191
# 25191
# 25191
# 25191
# 25191
# 25191
# 25191

# %%
lists[0]=np.array(lists[0])
lists[0].shape
# Out:
# (24191, 79)

# %%
from sklearn.metrics import classification_report

# %% [markdown]
# 1_predict on all 1000000 record
# #looing accros list we make above make the same operation that we mak on static on every dataframe on the list then fit model on it then fit adaptive modeling on it

# %% [markdown]
# https://scikit-learn.org/stable/modules/generated/sklearn.metrics.f1_score.html

# %%
from sklearn.metrics import f1_score
for i in range(1,len(lists)):
  df2 = pd.DataFrame(lists[i])
  df2.replace([np.inf, -np.inf], np.nan, inplace=True)
  df2 = df2.fillna(0)
  XX = df2.drop(['Label'],axis=1)
  yy = df2['Label']
  #print(XX)
  clf.fit(XX,yy)
  y_pred33 = clf.predict(X)
  encoder = ce.OrdinalEncoder()


  y_pred33 = encoder.fit_transform(y_pred33)
  
  print('Model accuracy : {0:0.4f}'. format(accuracy_score(y, y_pred33)))
  print(classification_report(y, y_pred33))
# Out:
# Model accuracy : 0.9454
#               precision    recall  f1-score   support
#
#            1       0.95      0.99      0.97     22744
#            2       0.89      0.50      0.64      2447
#
#     accuracy                           0.95     25191
#    macro avg       0.92      0.75      0.81     25191
# weighted avg       0.94      0.95      0.94     25191
#
# Model accuracy : 0.9445
#               precision    recall  f1-score   support
#
#            1       0.94      1.00      0.97     22744
#            2       0.94      0.46      0.61      2447
#
#     accuracy                           0.94     25191
#    macro avg       0.94      0.73      0.79     25191
# weighted avg       0.94      0.94      0.94     25191
#
# Model accuracy : 0.9585
#               precision    recall  f1-score   support
#
#            1       0.97      0.99      0.98     22744
#            2       0.86      0.68      0.76      2447
#
#     accuracy                           0.96     25191
#    macro avg       0.91      0.83      0.87     25191
# weighted avg       0.96      0.96      0.96     25191
#
# Model accuracy : 0.9599
#               precision    recall  f1-score   support
#
#            1       0.97      0.99      0.98     22744
#            2       0.88      0.68      0.77      2447
#
#     accuracy                           0.96     25191
#    macro avg       0.92      0.84      0.87     25191
# weighted avg       0.96      0.96      0.96     25191
#
# Model accuracy : 0.9475
#               precision    recall  f1-score   support
#
#            1       0.96      0.98      0.97     22744
#            2       0.80      0.61      0.69      2447
#
#     accuracy                           0.95     25191
#    macro avg       0.88      0.80      0.83     25191
# weighted avg       0.94      0.95      0.94     25191
#
# Model accuracy : 0.9538
#               precision    recall  f1-score   support
#
#            1       0.97      0.98      0.97     22744
#            2       0.77      0.75      0.76      2447
#
#     accuracy                           0.95     25191
#    macro avg       0.87      0.86      0.87     25191
# weighted avg       0.95      0.95      0.95     25191
#
# Model accuracy : 0.9568
#               precision    recall  f1-score   support
#
#            1       0.97      0.99      0.98     22744
#            2       0.84      0.69      0.76      2447
#
#     accuracy                           0.96     25191
#    macro avg       0.90      0.84      0.87     25191
# weighted avg       0.95      0.96      0.95     25191
#
# Model accuracy : 0.9709
#               precision    recall  f1-score   support
#
#            1       0.98      0.99      0.98     22744
#            2       0.88      0.81      0.84      2447
#
#     accuracy                           0.97     25191
#    macro avg       0.93      0.90      0.91     25191
# weighted avg       0.97      0.97      0.97     25191
#
# Model accuracy : 0.9616
#               precision    recall  f1-score   support
#
#            1       0.99      0.97      0.98     22744
#            2       0.76      0.88      0.82      2447
#
#     accuracy                           0.96     25191
#    macro avg       0.87      0.92      0.90     25191
# weighted avg       0.96      0.96      0.96     25191
#
# Model accuracy : 0.9607
#               precision    recall  f1-score   support
#
#            1       0.98      0.98      0.98     22744
#            2       0.81      0.78      0.80      2447
#
#     accuracy                           0.96     25191
#    macro avg       0.89      0.88      0.89     25191
# weighted avg       0.96      0.96      0.96     25191
#
# Model accuracy : 0.9622
#               precision    recall  f1-score   support
#
#            1       0.99      0.97      0.98     22744
#            2       0.77      0.87      0.82      2447
#
#     accuracy                           0.96     25191
#    macro avg       0.88      0.92      0.90     25191
# weighted avg       0.96      0.96      0.96     25191
#
# Model accuracy : 0.9546
#               precision    recall  f1-score   support
#
#            1       0.97      0.98      0.97     22744
#            2       0.80      0.72      0.75      2447
#
#     accuracy                           0.95     25191
#    macro avg       0.88      0.85      0.86     25191
# weighted avg       0.95      0.95      0.95     25191
#
# Model accuracy : 0.9581
#               precision    recall  f1-score   support
#
#            1       0.98      0.97      0.98     22744
#            2       0.77      0.80      0.79      2447
#
#     accuracy                           0.96     25191
#    macro avg       0.88      0.89      0.88     25191
# weighted avg       0.96      0.96      0.96     25191
#
# Model accuracy : 0.9357
#               precision    recall  f1-score   support
#
#            1       0.98      0.95      0.96     22744
#            2       0.63      0.80      0.71      2447
#
#     accuracy                           0.94     25191
#    macro avg       0.81      0.87      0.83     25191
# weighted avg       0.94      0.94      0.94     25191
#
# Model accuracy : 0.9576
#               precision    recall  f1-score   support
#
#            1       0.96      0.99      0.98     22744
#            2       0.91      0.62      0.74      2447
#
#     accuracy                           0.96     25191
#    macro avg       0.94      0.81      0.86     25191
# weighted avg       0.96      0.96      0.95     25191
#
# Model accuracy : 0.9530
#               precision    recall  f1-score   support
#
#            1       0.96      0.99      0.97     22744
#            2       0.92      0.57      0.70      2447
#
#     accuracy                           0.95     25191
#    macro avg       0.94      0.78      0.84     25191
# weighted avg       0.95      0.95      0.95     25191
#
# Model accuracy : 0.9669
#               precision    recall  f1-score   support
#
#            1       0.98      0.99      0.98     22744
#            2       0.85      0.79      0.82      2447
#
#     accuracy                           0.97     25191
#    macro avg       0.92      0.89      0.90     25191
# weighted avg       0.97      0.97      0.97     25191
#
# Model accuracy : 0.9652
#               precision    recall  f1-score   support
#
#            1       0.97      0.99      0.98     22744
#            2       0.87      0.76      0.81      2447
#
#     accuracy                           0.97     25191
#    macro avg       0.92      0.87      0.89     25191
# weighted avg       0.96      0.97      0.96     25191
#
# Model accuracy : 0.9633
#               precision    recall  f1-score   support
#
#            1       0.99      0.97      0.98     22744
#            2       0.77      0.89      0.83      2447
#
#     accuracy                           0.96     25191
#    macro avg       0.88      0.93      0.90     25191
# weighted avg       0.97      0.96      0.96     25191
#
# Model accuracy : 0.9642
#               precision    recall  f1-score   support
#
#            1       0.97      0.99      0.98     22744
#            2       0.90      0.71      0.79      2447
#
#     accuracy                           0.96     25191
#    macro avg       0.93      0.85      0.89     25191
# weighted avg       0.96      0.96      0.96     25191
#
# Model accuracy : 0.9560
#               precision    recall  f1-score   support
#
#            1       0.96      0.99      0.98     22744
#            2       0.91      0.61      0.73      2447
#
#     accuracy                           0.96     25191
#    macro avg       0.93      0.80      0.85     25191
# weighted avg       0.95      0.96      0.95     25191
#
# Model accuracy : 0.9662
#               precision    recall  f1-score   support
#
#            1       0.98      0.98      0.98     22744
#            2       0.83      0.82      0.82      2447
#
#     accuracy                           0.97     25191
#    macro avg       0.91      0.90      0.90     25191
# weighted avg       0.97      0.97      0.97     25191
#
# Model accuracy : 0.9568
#               precision    recall  f1-score   support
#
#            1       0.97      0.99      0.98     22744
#            2       0.85      0.68      0.75      2447
#
#     accuracy                           0.96     25191
#    macro avg       0.91      0.83      0.86     25191
# weighted avg       0.95      0.96      0.95     25191
#
# Model accuracy : 0.9657
#               precision    recall  f1-score   support
#
#            1       0.98      0.98      0.98     22744
#            2       0.81      0.85      0.83      2447
#
#     accuracy                           0.97     25191
#    macro avg       0.90      0.91      0.90     25191
# weighted avg       0.97      0.97      0.97     25191
#
# Model accuracy : 0.9649
#               precision    recall  f1-score   support
#
#            1       0.97      0.99      0.98     22744
#            2       0.93      0.69      0.79      2447
#
#     accuracy                           0.96     25191
#    macro avg       0.95      0.84      0.89     25191
# weighted avg       0.96      0.96      0.96     25191
#
# Model accuracy : 0.9570
#               precision    recall  f1-score   support
#
#            1       0.97      0.98      0.98     22744
#            2       0.81      0.72      0.77      2447
#
#     accuracy                           0.96     25191
#    macro avg       0.89      0.85      0.87     25191
# weighted avg       0.96      0.96      0.96     25191
#
# Model accuracy : 0.9588
#               precision    recall  f1-score   support
#
#            1       0.97      0.99      0.98     22744
#            2       0.84      0.71      0.77      2447
#
#     accuracy                           0.96     25191
#    macro avg       0.91      0.85      0.87     25191
# weighted avg       0.96      0.96      0.96     25191
#
# Model accuracy : 0.9605
#               precision    recall  f1-score   support
#
#            1       0.97      0.99      0.98     22744
#            2       0.87      0.69      0.77      2447
#
#     accuracy                           0.96     25191
#    macro avg       0.92      0.84      0.88     25191
# weighted avg       0.96      0.96      0.96     25191
#
# Model accuracy : 0.9518
#               precision    recall  f1-score   support
#
#            1       0.99      0.95      0.97     22744
#            2       0.69      0.93      0.79      2447
#
#     accuracy                           0.95     25191
#    macro avg       0.84      0.94      0.88     25191
# weighted avg       0.96      0.95      0.96     25191
#
# Model accuracy : 0.9535
#               precision    recall  f1-score   support
#
#            1       0.96      0.99      0.97     22744
#            2       0.91      0.58      0.71      2447
#
#     accuracy                           0.95     25191
#    macro avg       0.93      0.79      0.84     25191
# weighted avg       0.95      0.95      0.95     25191
#
# Model accuracy : 0.9502
#               precision    recall  f1-score   support
#
#            1       0.98      0.97      0.97     22744
#            2       0.72      0.81      0.76      2447
#
#     accuracy                           0.95     25191
#    macro avg       0.85      0.89      0.87     25191
# weighted avg       0.95      0.95      0.95     25191
#
# Model accuracy : 0.9593
#               precision    recall  f1-score   support
#
#            1       0.96      0.99      0.98     22744
#            2       0.91      0.64      0.75      2447
#
#     accuracy                           0.96     25191
#    macro avg       0.94      0.82      0.87     25191
# weighted avg       0.96      0.96      0.96     25191
#
# Model accuracy : 0.9571
#               precision    recall  f1-score   support
#
#            1       0.97      0.98      0.98     22744
#            2       0.79      0.76      0.78      2447
#
#     accuracy                           0.96     25191
#    macro avg       0.88      0.87      0.88     25191
# weighted avg       0.96      0.96      0.96     25191
#
# Model accuracy : 0.9583
#               precision    recall  f1-score   support
#
#            1       0.97      0.98      0.98     22744
#            2       0.82      0.74      0.77      2447
#
#     accuracy                           0.96     25191
#    macro avg       0.89      0.86      0.88     25191
# weighted avg       0.96      0.96      0.96     25191
#
# Model accuracy : 0.9618
#               precision    recall  f1-score   support
#
#            1       0.97      0.99      0.98     22744
#            2       0.88      0.70      0.78      2447
#
#     accuracy                           0.96     25191
#    macro avg       0.93      0.84      0.88     25191
# weighted avg       0.96      0.96      0.96     25191
#
# Model accuracy : 0.9641
#               precision    recall  f1-score   support
#
#            1       0.98      0.98      0.98     22744
#            2       0.80      0.84      0.82      2447
#
#     accuracy                           0.96     25191
#    macro avg       0.89      0.91      0.90     25191
# weighted avg       0.97      0.96      0.96     25191
#
# Model accuracy : 0.9654
#               precision    recall  f1-score   support
#
#            1       0.98      0.98      0.98     22744
#            2       0.83      0.81      0.82      2447
#
#     accuracy                           0.97     25191
#    macro avg       0.90      0.90      0.90     25191
# weighted avg       0.97      0.97      0.97     25191
#
# Model accuracy : 0.9567
#               precision    recall  f1-score   support
#
#            1       0.98      0.97      0.98     22744
#            2       0.74      0.85      0.79      2447
#
#     accuracy                           0.96     25191
#    macro avg       0.86      0.91      0.88     25191
# weighted avg       0.96      0.96      0.96     25191
#
# Model accuracy : 0.9280
#               precision    recall  f1-score   support
#
#            1       0.98      0.94      0.96     22744
#            2       0.60      0.79      0.68      2447
#
#     accuracy                           0.93     25191
#    macro avg       0.79      0.86      0.82     25191
# weighted avg       0.94      0.93      0.93     25191
#
# Model accuracy : 0.9515
#               precision    recall  f1-score   support
#
#            1       0.95      1.00      0.97     22744
#            2       0.94      0.54      0.68      2447
#
#     accuracy                           0.95     25191
#    macro avg       0.94      0.77      0.83     25191
# weighted avg       0.95      0.95      0.95     25191
#
# Model accuracy : 0.9624
#               precision    recall  f1-score   support
#
#            1       0.98      0.98      0.98     22744
#            2       0.79      0.84      0.81      2447
#
#     accuracy                           0.96     25191
#    macro avg       0.89      0.91      0.90     25191
# weighted avg       0.96      0.96      0.96     25191
#
# Model accuracy : 0.9265
#               precision    recall  f1-score   support
#
#            1       0.99      0.93      0.96     22744
#            2       0.58      0.93      0.71      2447
#
#     accuracy                           0.93     25191
#    macro avg       0.78      0.93      0.83     25191
# weighted avg       0.95      0.93      0.93     25191
#
# Model accuracy : 0.9392
#               precision    recall  f1-score   support
#
#            1       0.97      0.96      0.97     22744
#            2       0.68      0.70      0.69      2447
#
#     accuracy                           0.94     25191
#    macro avg       0.82      0.83      0.83     25191
# weighted avg       0.94      0.94      0.94     25191
#
# Model accuracy : 0.9579
#               precision    recall  f1-score   support
#
#            1       0.96      0.99      0.98     22744
#            2       0.91      0.63      0.74      2447
#
#     accuracy                           0.96     25191
#    macro avg       0.94      0.81      0.86     25191
# weighted avg       0.96      0.96      0.95     25191
#
# Model accuracy : 0.9611
#               precision    recall  f1-score   support
#
#            1       0.98      0.98      0.98     22744
#            2       0.82      0.77      0.79      2447
#
#     accuracy                           0.96     25191
#    macro avg       0.90      0.88      0.89     25191
# weighted avg       0.96      0.96      0.96     25191
#
# Model accuracy : 0.9590
#               precision    recall  f1-score   support
#
#            1       0.98      0.98      0.98     22744
#            2       0.79      0.78      0.79      2447
#
#     accuracy                           0.96     25191
#    macro avg       0.88      0.88      0.88     25191
# weighted avg       0.96      0.96      0.96     25191
#
# Model accuracy : 0.9464
#               precision    recall  f1-score   support
#
#            1       0.96      0.98      0.97     22744
#            2       0.78      0.63      0.70      2447
#
#     accuracy                           0.95     25191
#    macro avg       0.87      0.81      0.83     25191
# weighted avg       0.94      0.95      0.94     25191
#
# Model accuracy : 0.9355
#               precision    recall  f1-score   support
#
#            1       0.98      0.95      0.96     22744
#            2       0.63      0.80      0.71      2447
#
#     accuracy                           0.94     25191
#    macro avg       0.81      0.87      0.84     25191
# weighted avg       0.94      0.94      0.94     25191
#
# Model accuracy : 0.9639
#               precision    recall  f1-score   support
#
#            1       0.98      0.98      0.98     22744
#            2       0.84      0.77      0.81      2447
#
#     accuracy                           0.96     25191
#    macro avg       0.91      0.88      0.89     25191
# weighted avg       0.96      0.96      0.96     25191
#
# Model accuracy : 0.9592
#               precision    recall  f1-score   support
#
#            1       0.96      0.99      0.98     22744
#            2       0.90      0.65      0.76      2447
#
#     accuracy                           0.96     25191
#    macro avg       0.93      0.82      0.87     25191
# weighted avg       0.96      0.96      0.96     25191
#
# Model accuracy : 0.9575
#               precision    recall  f1-score   support
#
#            1       0.96      0.99      0.98     22744
#            2       0.89      0.64      0.74      2447
#
#     accuracy                           0.96     25191
#    macro avg       0.93      0.81      0.86     25191
# weighted avg       0.96      0.96      0.95     25191
#
# Model accuracy : 0.9586
#               precision    recall  f1-score   support
#
#            1       0.96      0.99      0.98     22744
#            2       0.88      0.67      0.76      2447
#
#     accuracy                           0.96     25191
#    macro avg       0.92      0.83      0.87     25191
# weighted avg       0.96      0.96      0.96     25191
#
# Model accuracy : 0.9669
#               precision    recall  f1-score   support
#
#            1       0.98      0.99      0.98     22744
#            2       0.87      0.77      0.82      2447
#
#     accuracy                           0.97     25191
#    macro avg       0.92      0.88      0.90     25191
# weighted avg       0.97      0.97      0.97     25191
#
# Model accuracy : 0.9586
#               precision    recall  f1-score   support
#
#            1       0.98      0.98      0.98     22744
#            2       0.79      0.78      0.79      2447
#
#     accuracy                           0.96     25191
#    macro avg       0.88      0.88      0.88     25191
# weighted avg       0.96      0.96      0.96     25191
#
# Model accuracy : 0.9505
#               precision    recall  f1-score   support
#
#            1       0.95      0.99      0.97     22744
#            2       0.91      0.54      0.68      2447
#
#     accuracy                           0.95     25191
#    macro avg       0.93      0.77      0.83     25191
# weighted avg       0.95      0.95      0.94     25191
#
# Model accuracy : 0.9533
#               precision    recall  f1-score   support
#
#            1       0.97      0.98      0.97     22744
#            2       0.81      0.67      0.74      2447
#
#     accuracy                           0.95     25191
#    macro avg       0.89      0.83      0.86     25191
# weighted avg       0.95      0.95      0.95     25191
#
# Model accuracy : 0.9635
#               precision    recall  f1-score   support
#
#            1       0.98      0.98      0.98     22744
#            2       0.84      0.78      0.81      2447
#
#     accuracy                           0.96     25191
#    macro avg       0.91      0.88      0.89     25191
# weighted avg       0.96      0.96      0.96     25191
#
# Model accuracy : 0.9712
#               precision    recall  f1-score   support
#
#            1       0.98      0.98      0.98     22744
#            2       0.85      0.85      0.85      2447
#
#     accuracy                           0.97     25191
#    macro avg       0.92      0.92      0.92     25191
# weighted avg       0.97      0.97      0.97     25191
#
# Model accuracy : 0.9669
#               precision    recall  f1-score   support
#
#            1       0.97      0.99      0.98     22744
#            2       0.91      0.73      0.81      2447
#
#     accuracy                           0.97     25191
#    macro avg       0.94      0.86      0.90     25191
# weighted avg       0.97      0.97      0.97     25191
#
# Model accuracy : 0.9630
#               precision    recall  f1-score   support
#
#            1       0.99      0.97      0.98     22744
#            2       0.77      0.88      0.82      2447
#
#     accuracy                           0.96     25191
#    macro avg       0.88      0.92      0.90     25191
# weighted avg       0.97      0.96      0.96     25191
#
# Model accuracy : 0.9640
#               precision    recall  f1-score   support
#
#            1       0.97      0.99      0.98     22744
#            2       0.91      0.70      0.79      2447
#
#     accuracy                           0.96     25191
#    macro avg       0.94      0.85      0.89     25191
# weighted avg       0.96      0.96      0.96     25191
#
# Model accuracy : 0.9575
#               precision    recall  f1-score   support
#
#            1       0.99      0.97      0.98     22744
#            2       0.74      0.87      0.80      2447
#
#     accuracy                           0.96     25191
#    macro avg       0.86      0.92      0.89     25191
# weighted avg       0.96      0.96      0.96     25191
#
# Model accuracy : 0.9562
#               precision    recall  f1-score   support
#
#            1       0.98      0.97      0.98     22744
#            2       0.76      0.80      0.78      2447
#
#     accuracy                           0.96     25191
#    macro avg       0.87      0.89      0.88     25191
# weighted avg       0.96      0.96      0.96     25191
#
# Model accuracy : 0.9535
#               precision    recall  f1-score   support
#
#            1       0.98      0.97      0.97     22744
#            2       0.75      0.79      0.77      2447
#
#     accuracy                           0.95     25191
#    macro avg       0.86      0.88      0.87     25191
# weighted avg       0.95      0.95      0.95     25191
#
# Model accuracy : 0.9543
#               precision    recall  f1-score   support
#
#            1       0.95      1.00      0.98     22744
#            2       0.95      0.56      0.70      2447
#
#     accuracy                           0.95     25191
#    macro avg       0.95      0.78      0.84     25191
# weighted avg       0.95      0.95      0.95     25191
#
# Model accuracy : 0.9674
#               precision    recall  f1-score   support
#
#            1       0.97      0.99      0.98     22744
#            2       0.91      0.74      0.81      2447
#
#     accuracy                           0.97     25191
#    macro avg       0.94      0.86      0.90     25191
# weighted avg       0.97      0.97      0.97     25191
#
# Model accuracy : 0.9606
#               precision    recall  f1-score   support
#
#            1       0.99      0.97      0.98     22744
#            2       0.74      0.91      0.82      2447
#
#     accuracy                           0.96     25191
#    macro avg       0.87      0.94      0.90     25191
# weighted avg       0.97      0.96      0.96     25191
#
# Model accuracy : 0.9572
#               precision    recall  f1-score   support
#
#            1       0.99      0.97      0.98     22744
#            2       0.73      0.88      0.80      2447
#
#     accuracy                           0.96     25191
#    macro avg       0.86      0.92      0.89     25191
# weighted avg       0.96      0.96      0.96     25191
#
# Model accuracy : 0.9447
#               precision    recall  f1-score   support
#
#            1       0.95      1.00      0.97     22744
#            2       0.92      0.47      0.62      2447
#
#     accuracy                           0.94     25191
#    macro avg       0.93      0.73      0.80     25191
# weighted avg       0.94      0.94      0.94     25191
#
# Model accuracy : 0.9344
#               precision    recall  f1-score   support
#
#            1       0.99      0.94      0.96     22744
#            2       0.61      0.89      0.72      2447
#
#     accuracy                           0.93     25191
#    macro avg       0.80      0.91      0.84     25191
# weighted avg       0.95      0.93      0.94     25191
#
# Model accuracy : 0.9666
#               precision    recall  f1-score   support
#
#            1       0.97      0.99      0.98     22744
#            2       0.88      0.76      0.81      2447
#
#     accuracy                           0.97     25191
#    macro avg       0.93      0.87      0.90     25191
# weighted avg       0.97      0.97      0.97     25191
#
# Model accuracy : 0.9336
#               precision    recall  f1-score   support
#
#            1       0.97      0.95      0.96     22744
#            2       0.63      0.75      0.69      2447
#
#     accuracy                           0.93     25191
#    macro avg       0.80      0.85      0.82     25191
# weighted avg       0.94      0.93      0.94     25191
#
# Model accuracy : 0.9596
#               precision    recall  f1-score   support
#
#            1       0.97      0.99      0.98     22744
#            2       0.86      0.69      0.77      2447
#
#     accuracy                           0.96     25191
#    macro avg       0.92      0.84      0.87     25191
# weighted avg       0.96      0.96      0.96     25191
#
# Model accuracy : 0.9530
#               precision    recall  f1-score   support
#
#            1       0.97      0.98      0.97     22744
#            2       0.77      0.74      0.75      2447
#
#     accuracy                           0.95     25191
#    macro avg       0.87      0.86      0.86     25191
# weighted avg       0.95      0.95      0.95     25191
#
# Model accuracy : 0.9679
#               precision    recall  f1-score   support
#
#            1       0.98      0.98      0.98     22744
#            2       0.84      0.83      0.83      2447
#
#     accuracy                           0.97     25191
#    macro avg       0.91      0.91      0.91     25191
# weighted avg       0.97      0.97      0.97     25191
#
# Model accuracy : 0.9565
#               precision    recall  f1-score   support
#
#            1       0.97      0.98      0.98     22744
#            2       0.81      0.73      0.76      2447
#
#     accuracy                           0.96     25191
#    macro avg       0.89      0.85      0.87     25191
# weighted avg       0.95      0.96      0.96     25191
#
# Model accuracy : 0.9668
#               precision    recall  f1-score   support
#
#            1       0.98      0.98      0.98     22744
#            2       0.83      0.83      0.83      2447
#
#     accuracy                           0.97     25191
#    macro avg       0.90      0.91      0.91     25191
# weighted avg       0.97      0.97      0.97     25191
#
# Model accuracy : 0.9576
#               precision    recall  f1-score   support
#
#            1       0.97      0.98      0.98     22744
#            2       0.81      0.74      0.77      2447
#
#     accuracy                           0.96     25191
#    macro avg       0.89      0.86      0.87     25191
# weighted avg       0.96      0.96      0.96     25191
#
# Model accuracy : 0.9575
#               precision    recall  f1-score   support
#
#            1       0.97      0.98      0.98     22744
#            2       0.80      0.75      0.78      2447
#
#     accuracy                           0.96     25191
#    macro avg       0.89      0.87      0.88     25191
# weighted avg       0.96      0.96      0.96     25191
#
# Model accuracy : 0.9602
#               precision    recall  f1-score   support
#
#            1       0.96      0.99      0.98     22744
#            2       0.93      0.64      0.76      2447
#
#     accuracy                           0.96     25191
#    macro avg       0.94      0.82      0.87     25191
# weighted avg       0.96      0.96      0.96     25191
#
# Model accuracy : 0.9686
#               precision    recall  f1-score   support
#
#            1       0.98      0.99      0.98     22744
#            2       0.86      0.81      0.83      2447
#
#     accuracy                           0.97     25191
#    macro avg       0.92      0.90      0.91     25191
# weighted avg       0.97      0.97      0.97     25191
#
# Model accuracy : 0.9631
#               precision    recall  f1-score   support
#
#            1       0.99      0.97      0.98     22744
#            2       0.77      0.87      0.82      2447
#
#     accuracy                           0.96     25191
#    macro avg       0.88      0.92      0.90     25191
# weighted avg       0.97      0.96      0.96     25191
#
# Model accuracy : 0.9621
#               precision    recall  f1-score   support
#
#            1       0.97      0.99      0.98     22744
#            2       0.92      0.67      0.77      2447
#
#     accuracy                           0.96     25191
#    macro avg       0.94      0.83      0.88     25191
# weighted avg       0.96      0.96      0.96     25191
#
# Model accuracy : 0.9662
#               precision    recall  f1-score   support
#
#            1       0.97      0.99      0.98     22744
#            2       0.88      0.76      0.81      2447
#
#     accuracy                           0.97     25191
#    macro avg       0.93      0.87      0.90     25191
# weighted avg       0.96      0.97      0.97     25191
#
# Model accuracy : 0.9705
#               precision    recall  f1-score   support
#
#            1       0.98      0.99      0.98     22744
#            2       0.92      0.77      0.83      2447
#
#     accuracy                           0.97     25191
#    macro avg       0.95      0.88      0.91     25191
# weighted avg       0.97      0.97      0.97     25191
#
# Model accuracy : 0.9644
#               precision    recall  f1-score   support
#
#            1       0.97      0.99      0.98     22744
#            2       0.92      0.69      0.79      2447
#
#     accuracy                           0.96     25191
#    macro avg       0.94      0.84      0.89     25191
# weighted avg       0.96      0.96      0.96     25191
#
# Model accuracy : 0.9529
#               precision    recall  f1-score   support
#
#            1       0.99      0.96      0.97     22744
#            2       0.70      0.90      0.79      2447
#
#     accuracy                           0.95     25191
#    macro avg       0.84      0.93      0.88     25191
# weighted avg       0.96      0.95      0.96     25191
#
# Model accuracy : 0.9524
#               precision    recall  f1-score   support
#
#            1       0.98      0.97      0.97     22744
#            2       0.74      0.80      0.77      2447
#
#     accuracy                           0.95     25191
#    macro avg       0.86      0.88      0.87     25191
# weighted avg       0.95      0.95      0.95     25191
#
# Model accuracy : 0.9518
#               precision    recall  f1-score   support
#
#            1       0.96      0.98      0.97     22744
#            2       0.81      0.66      0.73      2447
#
#     accuracy                           0.95     25191
#    macro avg       0.89      0.82      0.85     25191
# weighted avg       0.95      0.95      0.95     25191
#
# Model accuracy : 0.9586
#               precision    recall  f1-score   support
#
#            1       0.99      0.96      0.98     22744
#            2       0.73      0.92      0.81      2447
#
#     accuracy                           0.96     25191
#    macro avg       0.86      0.94      0.89     25191
# weighted avg       0.97      0.96      0.96     25191
#
# Model accuracy : 0.9549
#               precision    recall  f1-score   support
#
#            1       0.97      0.98      0.98     22744
#            2       0.81      0.70      0.75      2447
#
#     accuracy                           0.95     25191
#    macro avg       0.89      0.84      0.86     25191
# weighted avg       0.95      0.95      0.95     25191
#
# Model accuracy : 0.9605
#               precision    recall  f1-score   support
#
#            1       0.96      0.99      0.98     22744
#            2       0.91      0.66      0.76      2447
#
#     accuracy                           0.96     25191
#    macro avg       0.94      0.83      0.87     25191
# weighted avg       0.96      0.96      0.96     25191
#
# Model accuracy : 0.9572
#               precision    recall  f1-score   support
#
#            1       0.97      0.99      0.98     22744
#            2       0.84      0.69      0.76      2447
#
#     accuracy                           0.96     25191
#    macro avg       0.90      0.84      0.87     25191
# weighted avg       0.96      0.96      0.96     25191
#
# Model accuracy : 0.9664
#               precision    recall  f1-score   support
#
#            1       0.99      0.98      0.98     22744
#            2       0.80      0.87      0.83      2447
#
#     accuracy                           0.97     25191
#    macro avg       0.89      0.92      0.91     25191
# weighted avg       0.97      0.97      0.97     25191
#
# Model accuracy : 0.9623
#               precision    recall  f1-score   support
#
#            1       0.99      0.97      0.98     22744
#            2       0.76      0.89      0.82      2447
#
#     accuracy                           0.96     25191
#    macro avg       0.88      0.93      0.90     25191
# weighted avg       0.97      0.96      0.96     25191
#
# Model accuracy : 0.9446
#               precision    recall  f1-score   support
#
#            1       0.96      0.97      0.97     22744
#            2       0.74      0.67      0.70      2447
#
#     accuracy                           0.94     25191
#    macro avg       0.85      0.82      0.84     25191
# weighted avg       0.94      0.94      0.94     25191
#
# Model accuracy : 0.9392
#               precision    recall  f1-score   support
#
#            1       0.94      1.00      0.97     22744
#            2       0.97      0.39      0.55      2447
#
#     accuracy                           0.94     25191
#    macro avg       0.95      0.69      0.76     25191
# weighted avg       0.94      0.94      0.93     25191
#
# Model accuracy : 0.9315
#               precision    recall  f1-score   support
#
#            1       0.98      0.94      0.96     22744
#            2       0.61      0.84      0.70      2447
#
#     accuracy                           0.93     25191
#    macro avg       0.79      0.89      0.83     25191
# weighted avg       0.95      0.93      0.94     25191

# %%
 y_pred33
# Out:
#        0
# 0      1
# 1      1
# 2      2
# 3      1
# 4      2
# ...   ..
# 25186  1
# 25187  2
# 25188  1
# 25189  1
# 25190  1
#
# [25191 rows x 1 columns]

# %%
encoder = ce.OrdinalEncoder()


y_pred33 = encoder.fit_transform(y_pred33)

# %%
y_pred33
# Out:
#        0
# 0      1
# 1      1
# 2      2
# 3      1
# 4      2
# ...   ..
# 25186  1
# 25187  2
# 25188  1
# 25189  1
# 25190  1
#
# [25191 rows x 1 columns]

# %%
y
# Out:
# 0        1
# 1        1
# 2        2
# 3        1
# 4        1
#         ..
# 25186    1
# 25187    2
# 25188    1
# 25189    1
# 25190    1
# Name: Label, Length: 25191, dtype: int64

# %% [markdown]
# #predict on all 100000 data

# %% [markdown]
# #looing accros list we make above make the same operation that we mak on static on every dataframe on the list then fit model on it then fit adaptive modeling on it

# %%
from sklearn.metrics import f1_score
accuracy = []
f1score = []
for i in range(1,len(lists)):
  df2 = pd.DataFrame(lists[i])
  df2.replace([np.inf, -np.inf], np.nan, inplace=True)
  df2 = df2.fillna(0)
  XX = df2.drop(['Label'],axis=1)
  yy = df2['Label']
  #print(XX)
  clf.fit(XX,yy)
  y_pred33 = clf.predict(X)
  encoder = ce.OrdinalEncoder()


  y_pred33 = encoder.fit_transform(y_pred33)
  
  accuracy.append(accuracy_score(y, y_pred33))
  f1score.append(f1_score(y, y_pred33, average='weighted'))

# %%
print(accuracy)
# Out:
# [0.9454170140129411, 0.9444642928029852, 0.9585169306498352, 0.9599063157476877, 0.947481243301179, 0.9538327180342185, 0.9567702750982494, 0.970862609662181, 0.9615735778651106, 0.9607002500893176, 0.9622087253384145, 0.9545869556587671, 0.9580802667619388, 0.9356516216108928, 0.9576436028740423, 0.9529990869755072, 0.9668929379540312, 0.9651859791195269, 0.9632805366996149, 0.9641935611924893, 0.9560160374737009, 0.9662180937636458, 0.9567702750982494, 0.9656623397245048, 0.9649477988170378, 0.9570084554007383, 0.9587948076694057, 0.9605017665039102, 0.9518478821801437, 0.9535151442975666, 0.9502203167798023, 0.9593108649914652, 0.9570878488349014, 0.9583184470644278, 0.9618117581675996, 0.9640744710412449, 0.9654241594220158, 0.9566511849470049, 0.9279504584970822, 0.9514906117264103, 0.962407208923822, 0.9265213766821484, 0.9392243261482276, 0.9578817831765313, 0.9610972172601326, 0.9589535945377318, 0.946369735222897, 0.9354531380254852, 0.9638759874558374, 0.9592314715573023, 0.9575245127227978, 0.9585566273669167, 0.9668929379540312, 0.9586360208010798, 0.9504584970822912, 0.9533166607121591, 0.9635187170021039, 0.9712198801159144, 0.9669326346711127, 0.9630026596800445, 0.9640347743241634, 0.9574848160057163, 0.9562145210591084, 0.9534754475804851, 0.954348775356278, 0.9674089952760907, 0.9605811599380731, 0.9572466357032273, 0.9446627763883927, 0.9344210233813663, 0.9665753642173792, 0.9336270890397365, 0.9596284387281172, 0.9529593902584256, 0.9678853558810686, 0.9564923980786789, 0.9668135445198682, 0.9575642094398793, 0.9574848160057163, 0.9601841927672582, 0.9685998967885356, 0.9630820531142075, 0.9621293319042515, 0.9662180937636458, 0.9704656424913659, 0.9644317414949783, 0.9529196935413441, 0.9524433329363662, 0.9517684887459807, 0.9586360208010798, 0.954904529395419, 0.9604620697868286, 0.9572466357032273, 0.9663768806319717, 0.9622881187725775, 0.9445833829542297, 0.939184629431146, 0.9315231630344171]

# %%
m_dict = {'Accuarcy': accuracy, 'f1_score': f1score}

# %%
df1 = pd.DataFrame(m_dict)

# %%
df1
# Out:
#     Accuarcy  f1_score
# 0   0.945417  0.938365
# 1   0.944464  0.935575
# 2   0.958517  0.956319
# 3   0.959906  0.957693
# 4   0.947481  0.944224
# ..       ...       ...
# 93  0.966377  0.966971
# 94  0.962288  0.963563
# 95  0.944583  0.943413
# 96  0.939185  0.927082
# 97  0.931523  0.936263
#
# [98 rows x 2 columns]

# %%
df1.to_csv('df.csv', index=False)

# %%
import matplotlib.pyplot as plt
import pandas as pd
ax=plt.gca()
df1.reset_index().plot(kind='line',x='index',y='Accuarcy',ax=ax)
df1.reset_index().plot(kind='line',x='index',y='f1_score',ax=ax)
plt.title("accuracy graph")
# Out:
# Text(0.5, 1.0, 'accuracy graph')

# %%
import matplotlib.pyplot as plt
import pandas as pd
ax=plt.gca()
df1.reset_index().plot(kind='line',x='index',y='f1_score',ax=ax)
plt.title("f1_score graph")
# Out:
# Text(0.5, 1.0, 'f1_score graph')

# %% [markdown]
# #predict with windowing on every 1000
#
# #looing accros list we make above make the same operation that we mak on static on every dataframe on the list then fit model on it then fit adaptive modeling on it  then now predict on every 1000 from 100000 in iteration

# %%
from sklearn.metrics import f1_score
accuracy = []
f1score = []
for i in range(1,len(lists)):

  df2 = pd.DataFrame(lists[i])
  df2.replace([np.inf, -np.inf], np.nan, inplace=True)
  df2 = df2.fillna(0)
  XX = df2.drop(['Label'],axis=1)
  yy = df2['Label']
  #print(XX)
  rfc.fit(XX,yy)
  for j in range(1,100):
      X2 = ts[(1000*j)-1000:(1000*j)].drop(['Label'],axis=1)
      y2 = ts[(1000*j)-1000:(1000*j)]['Label']
      y_pred33 = rfc.predict(X2)
      encoder = ce.OrdinalEncoder()


  y_pred33 = encoder.fit_transform(y_pred33)
  accuracy.append(accuracy_score(y2, y_pred33))
  f1score.append(f1_score(y2, y_pred33, average='weighted'))

# %%
m_dict = {'Accuarcy': accuracy, 'f1_score': f1score}

# %%
df = pd.DataFrame(m_dict)

# %%
import matplotlib.pyplot as plt
import pandas as pd
ax=plt.gca()
df.reset_index().plot(kind='line',x='index',y='Accuarcy',ax=ax)
df.reset_index().plot(kind='line',x='index',y='f1_score',ax=ax)
plt.title("accuracy graph")
# Out:
# Text(0.5, 1.0, 'accuracy graph')

# %%
import matplotlib.pyplot as plt
import pandas as pd
ax=plt.gca()
#df.reset_index().plot(kind='line',x='index',y='Accuarcy',ax=ax)
df.reset_index().plot(kind='line',x='index',y='f1_score',ax=ax)
plt.title("accuracy graph")
# Out:
# Text(0.5, 1.0, 'accuracy graph')

# %% [markdown]
# results show that
# .RSNDOMFOREST IS BETTER ON THIS PROBLEM  ACCORDING TO ACCURACY AND F1SCORE IT GIVE ME BETTER RESULT on Static data show that RANDOMFOREST is better on this problem according to f1score and accuracy and confusion matrix the fp for the classes decreases,when predict on every 1000 from 100000 in iteration the accuracy ranges from .99 to be 1 now  which is better berformance
# .THE MODEL GIVE BETTER RESULT WHEN REMOVE SORCE COLUMN SO ITS BETTER TO ANALYZE DATA TO KNOW IF IT CONTAIN  COLUMN THAT MAKE RESULT WORSE
